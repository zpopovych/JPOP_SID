# %%
include("LiPoSID.jl")
using QuantumOptics
using LinearAlgebra
using Plots

function timeevolution_kraus(t_span, ρ₀, K)
    ρ = [ρ₀]
    for t = 2:length(t_span)
        push!(ρ, Hermitian(sum([K[i]* ρ[end] * K[i]' for i = 1:length(K)])))
    end
    return ρ
end
# Out:
# (process:17352): GLib-GIO-WARNING **: 13:05:34.768: Unexpectedly, UWP app `Microsoft.MSPaint_6.2203.1037.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.MSPaint_8wekyb3d8bbwe!Microsoft.MSPaint') supports 17 extensions but has no verbs

# %%
tₘₐₓ = 2.0 # maximum time 
Δt = 0.05     # time step
time_span = [0:Δt:tₘₐₓ;] # time span

ρ₀ = LiPoSID.rand_dm(2)       

K1 = rand(2,2) + im*rand(2,2)
K2 = rand(2,2) + im*rand(2,2)

K_list = [K1, K2]
        
ρ = timeevolution_kraus(time_span, ρ₀, K_list);

# %%
plot(LiPoSID.bloch(ρ)')
