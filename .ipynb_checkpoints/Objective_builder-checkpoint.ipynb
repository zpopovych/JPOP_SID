# %%
using Symbolics
using LinearAlgebra
using DynamicPolynomials

# %%
@polyvar x[1:4]
# Out:
# (PolyVar{true}[x₁, x₂, x₃, x₄],)

# %%
H = [ 1.0 * x[1]              x[3] + im * x[4]
      x[3] - im * x[4]  x[2]  ]
println(H)
H' == H
# Out:
# Polynomial{true, ComplexF64}[x₁ x₃ + (0.0 + 1.0im)x₄; x₃ + (0.0 - 1.0im)x₄ x₂]
# true

# %%
@polyvar a[1:2, 1:2]
@polyvar b[1:2, 1:2]
A = 1.0 * a + im * b
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  a₁₋₁ + (0.0+1.0im)b₁₋₁  a₁₋₂ + (0.0+1.0im)b₁₋₂
#  a₂₋₁ + (0.0+1.0im)b₂₋₁  a₂₋₂ + (0.0+1.0im)b₂₋₂

# %%
A'
# Out:
# 2×2 adjoint(::Matrix{Polynomial{true, ComplexF64}}) with eltype Polynomial{true, ComplexF64}:
#  a₁₋₁ + (0.0-1.0im)b₁₋₁  a₂₋₁ + (0.0-1.0im)b₂₋₁
#  a₁₋₂ + (0.0-1.0im)b₁₋₂  a₂₋₂ + (0.0-1.0im)b₂₋₂

# %%
function frobenius_norm2(m)
    return tr(m * m')
end

println(A)
frobenius_norm2(A)
# Out:
# Polynomial{true, ComplexF64}[a₁₋₁ + (0.0 + 1.0im)b₁₋₁ a₁₋₂ + (0.0 + 1.0im)b₁₋₂; a₂₋₁ + (0.0 + 1.0im)b₂₋₁ a₂₋₂ + (0.0 + 1.0im)b₂₋₂]
# a₁₋₁² + a₂₋₁² + a₁₋₂² + a₂₋₂² + b₁₋₁² + b₂₋₁² + b₁₋₂² + b₂₋₂²

# %%
function lindblad_rhs(rho, H, A)
    """
    Right hand side of the Lindblad master equation
    """
    return -1.0im * (H * rho - rho * H) + A * rho * A' - (A' * A  * rho + rho * A' * A) / 2
    
end
# Out:
# lindblad_rhs (generic function with 1 method)

# %%
ρ1 = [.5 -im
     +im  .5]
ρ2 = [.6 0
     0  .4]
ρ3 = [.7 0
     0  .3]
ρ4 = [.9 0
     0  .1]
# Out:
# 2×2 Matrix{Float64}:
#  0.9  0.0
#  0.0  0.1

# %%
ρ = [ρ1;;; ρ2;;; ρ3;;; ρ4]
# Out:
# 2×2×4 Array{ComplexF64, 3}:
# [:, :, 1] =
#  0.5+0.0im  0.0-1.0im
#  0.0+1.0im  0.5+0.0im
#
# [:, :, 2] =
#  0.6+0.0im  0.0+0.0im
#  0.0+0.0im  0.4+0.0im
#
# [:, :, 3] =
#  0.7+0.0im  0.0+0.0im
#  0.0+0.0im  0.3+0.0im
#
# [:, :, 4] =
#  0.9+0.0im  0.0+0.0im
#  0.0+0.0im  0.1+0.0im

# %%
obj = frobenius_norm2(lindblad_rhs(ρ1))
for i in 2:4
    cur_obj = frobenius_norm2(lindblad_rhs(ρ[:, :, i]))
    obj += cur_obj
end

# %%
println(nterms(obj))
obj
# Out:
# 199
# (0.5 + 0.0im)a₁₋₁⁴ + (-2.0 + 0.0im)a₁₋₁³a₂₋₂ + -a₁₋₁³b₂₋₁ + -a₁₋₁³b₁₋₂ + (4.82 + 0.0im)a₁₋₁²a₂₋₁² + (-3.4 + 0.0im)a₁₋₁²a₂₋₁a₁₋₂ + a₁₋₁²a₂₋₁b₁₋₁ + (-3.0 + 0.0im)a₁₋₁²a₂₋₁b₂₋₂ + (3.0 + 0.0im)a₁₋₁²a₁₋₂² + a₁₋₁²a₁₋₂b₁₋₁ + a₁₋₁²a₁₋₂b₂₋₂ + (3.0 + 0.0im)a₁₋₁²a₂₋₂² + (3.0 + 0.0im)a₁₋₁²a₂₋₂b₂₋₁ + (3.0 + 0.0im)a₁₋₁²a₂₋₂b₁₋₂ + a₁₋₁²b₁₋₁² + (-2.0 + 0.0im)a₁₋₁²b₁₋₁b₂₋₂ + (4.82 + 0.0im)a₁₋₁²b₂₋₁² + (7.3999999999999995 + 0.0im)a₁₋₁²b₂₋₁b₁₋₂ + (5.0 + 0.0im)a₁₋₁²b₁₋₂² + (3.0 + 0.0im)a₁₋₁²b₂₋₂² + (-7.3999999999999995 + 0.0im)a₁₋₁a₂₋₁²a₂₋₂ + -a₁₋₁a₂₋₁²b₂₋₁ + -a₁₋₁a₂₋₁²b₁₋₂ + (3.16 + 0.0im)a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + (4.0 + 0.0im)a₁₋₁a₂₋₁a₂₋₂b₂₋₂ + (-10.8 + 0.0im)a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + (7.16 + 0.0im)a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + (-4.6 + 0.0im)a₁₋₁a₁₋₂²a₂₋₂ + (-3.0 + 0.0im)a₁₋₁a₁₋₂²b₂₋₁ + (-3.0 + 0.0im)a₁₋₁a₁₋₂²b₁₋₂ + (-4.0 + 0.0im)a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + (-10.8 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₁ + (-4.0 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + (3.16 + 0.0im)a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + (-2.0 + 0.0im)a₁₋₁a₂₋₂³ + (-3.0 + 0.0im)a₁₋₁a₂₋₂²b₂₋₁ + (-3.0 + 0.0im)a₁₋₁a₂₋₂²b₁₋₂ + (-2.0 + 0.0im)a₁₋₁a₂₋₂b₁₋₁² + (-7.3999999999999995 + 0.0im)a₁₋₁a₂₋₂b₂₋₁² + (-7.16 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₁₋₂ + (-4.6 + 0.0im)a₁₋₁a₂₋₂b₁₋₂² + (-2.0 + 0.0im)a₁₋₁a₂₋₂b₂₋₂² + -a₁₋₁b₁₋₁²b₂₋₁ + -a₁₋₁b₁₋₁²b₁₋₂ + (4.0 + 0.0im)a₁₋₁b₁₋₁b₁₋₂b₂₋₂ + -a₁₋₁b₂₋₁³ + -a₁₋₁b₂₋₁²b₁₋₂ + (-3.0 + 0.0im)a₁₋₁b₂₋₁b₁₋₂² + a₁₋₁b₂₋₁b₂₋₂² + (-3.0 + 0.0im)a₁₋₁b₁₋₂³ + (-3.0 + 0.0im)a₁₋₁b₁₋₂b₂₋₂² + (4.32 + 0.0im)a₂₋₁⁴ + (2.0 + 0.0im)a₂₋₁³a₁₋₂ + a₂₋₁³b₁₋₁ + (-3.0 + 0.0im)a₂₋₁³b₂₋₂ + (-0.15999999999999998 + 0.0im)a₂₋₁²a₁₋₂² + a₂₋₁²a₁₋₂b₁₋₁ + (-3.0 + 0.0im)a₂₋₁²a₁₋₂b₂₋₂ + (3.0 + 0.0im)a₂₋₁²a₂₋₂² + (3.0 + 0.0im)a₂₋₁²a₂₋₂b₂₋₁ + (3.0 + 0.0im)a₂₋₁²a₂₋₂b₁₋₂ + (4.82 + 0.0im)a₂₋₁²b₁₋₁² + (-7.3999999999999995 + 0.0im)a₂₋₁²b₁₋₁b₂₋₂ + (8.64 + 0.0im)a₂₋₁²b₂₋₁² + (2.0 + 0.0im)a₂₋₁²b₂₋₁b₁₋₂ + (-0.15999999999999998 + 0.0im)a₂₋₁²b₁₋₂² + (5.0 + 0.0im)a₂₋₁²b₂₋₂² + (2.0 + 0.0im)a₂₋₁a₁₋₂³ + (3.0 + 0.0im)a₂₋₁a₁₋₂²b₁₋₁ + -a₂₋₁a₁₋₂²b₂₋₂ + (-0.6000000000000001 + 0.0im)a₂₋₁a₁₋₂a₂₋₂² + (7.3999999999999995 + 0.0im)a₂₋₁a₁₋₂b₁₋₁² + (-7.16 + 0.0im)a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + (2.0 + 0.0im)a₂₋₁a₁₋₂b₂₋₁² + (2.0 + 0.0im)a₂₋₁a₁₋₂b₁₋₂² + (4.6 + 0.0im)a₂₋₁a₁₋₂b₂₋₂² + -a₂₋₁a₂₋₂²b₁₋₁ + -a₂₋₁a₂₋₂²b₂₋₂ + (3.16 + 0.0im)a₂₋₁a₂₋₂b₁₋₁b₁₋₂ + (-4.0 + 0.0im)a₂₋₁a₂₋₂b₂₋₁b₂₋₂ + (-5.2 + 0.0im)a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + a₂₋₁b₁₋₁³ + (-3.0 + 0.0im)a₂₋₁b₁₋₁²b₂₋₂ + a₂₋₁b₁₋₁b₂₋₁² + (3.0 + 0.0im)a₂₋₁b₁₋₁b₁₋₂² + (3.0 + 0.0im)a₂₋₁b₁₋₁b₂₋₂² + (-3.0 + 0.0im)a₂₋₁b₂₋₁²b₂₋₂ + -a₂₋₁b₁₋₂²b₂₋₂ + -a₂₋₁b₂₋₂³ + (1.52 + 0.0im)a₁₋₂⁴ + (3.0 + 0.0im)a₁₋₂³b₁₋₁ + -a₁₋₂³b₂₋₂ + (2.02 + 0.0im)a₁₋₂²a₂₋₂² + a₁₋₂²a₂₋₂b₂₋₁ + a₁₋₂²a₂₋₂b₁₋₂ + (5.0 + 0.0im)a₁₋₂²b₁₋₁² + (-4.6 + 0.0im)a₁₋₂²b₁₋₁b₂₋₂ + (-0.15999999999999998 + 0.0im)a₁₋₂²b₂₋₁² + (2.0 + 0.0im)a₁₋₂²b₂₋₁b₁₋₂ + (3.04 + 0.0im)a₁₋₂²b₁₋₂² + (2.02 + 0.0im)a₁₋₂²b₂₋₂² + (3.0 + 0.0im)a₁₋₂a₂₋₂²b₁₋₁ + -a₁₋₂a₂₋₂²b₂₋₂ + (7.16 + 0.0im)a₁₋₂a₂₋₂b₁₋₁b₂₋₁ + (-5.2 + 0.0im)a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + a₁₋₂b₁₋₁³ + (-3.0 + 0.0im)a₁₋₂b₁₋₁²b₂₋₂ + a₁₋₂b₁₋₁b₂₋₁² + (3.0 + 0.0im)a₁₋₂b₁₋₁b₁₋₂² + (3.0 + 0.0im)a₁₋₂b₁₋₁b₂₋₂² + (-3.0 + 0.0im)a₁₋₂b₂₋₁²b₂₋₂ + -a₁₋₂b₁₋₂²b₂₋₂ + -a₁₋₂b₂₋₂³ + (0.5 + 0.0im)a₂₋₂⁴ + a₂₋₂³b₂₋₁ + a₂₋₂³b₁₋₂ + (3.0 + 0.0im)a₂₋₂²b₁₋₁² + (-2.0 + 0.0im)a₂₋₂²b₁₋₁b₂₋₂ + (5.0 + 0.0im)a₂₋₂²b₂₋₁² + (4.6 + 0.0im)a₂₋₂²b₂₋₁b₁₋₂ + (2.02 + 0.0im)a₂₋₂²b₁₋₂² + a₂₋₂²b₂₋₂² + (3.0 + 0.0im)a₂₋₂b₁₋₁²b₂₋₁ + -a₂₋₂b₁₋₁²b₁₋₂ + (-4.0 + 0.0im)a₂₋₂b₁₋₁b₂₋₁b₂₋₂ + (3.0 + 0.0im)a₂₋₂b₂₋₁³ + (3.0 + 0.0im)a₂₋₂b₂₋₁²b₁₋₂ + a₂₋₂b₂₋₁b₁₋₂² + a₂₋₂b₂₋₁b₂₋₂² + a₂₋₂b₁₋₂³ + a₂₋₂b₁₋₂b₂₋₂² + (0.5 + 0.0im)b₁₋₁⁴ + (-2.0 + 0.0im)b₁₋₁³b₂₋₂ + (4.82 + 0.0im)b₁₋₁²b₂₋₁² + (-3.4 + 0.0im)b₁₋₁²b₂₋₁b₁₋₂ + (3.0 + 0.0im)b₁₋₁²b₁₋₂² + (3.0 + 0.0im)b₁₋₁²b₂₋₂² + (-7.3999999999999995 + 0.0im)b₁₋₁b₂₋₁²b₂₋₂ + (3.16 + 0.0im)b₁₋₁b₂₋₁b₁₋₂b₂₋₂ + (-4.6 + 0.0im)b₁₋₁b₁₋₂²b₂₋₂ + (-2.0 + 0.0im)b₁₋₁b₂₋₂³ + (4.32 + 0.0im)b₂₋₁⁴ + (2.0 + 0.0im)b₂₋₁³b₁₋₂ + (-0.15999999999999998 + 0.0im)b₂₋₁²b₁₋₂² + (3.0 + 0.0im)b₂₋₁²b₂₋₂² + (2.0 + 0.0im)b₂₋₁b₁₋₂³ + (-0.6000000000000001 + 0.0im)b₂₋₁b₁₋₂b₂₋₂² + (1.52 + 0.0im)b₁₋₂⁴ + (2.02 + 0.0im)b₁₋₂²b₂₋₂² + (0.5 + 0.0im)b₂₋₂⁴ + (-2.0 + 0.0im)x₁a₁₋₁a₂₋₁ + (2.0 + 0.0im)x₁a₁₋₁a₁₋₂ + (4.0 +  ...

# %%
terms(obj)
coefficients(obj)
# Out:
# 199-element Vector{ComplexF64}:
#                  0.5 + 0.0im
#                 -2.0 + 0.0im
#                 -1.0 + 0.0im
#                 -1.0 + 0.0im
#                 4.82 + 0.0im
#                 -3.4 + 0.0im
#                  1.0 + 0.0im
#                 -3.0 + 0.0im
#                  3.0 + 0.0im
#                  1.0 + 0.0im
#                  1.0 + 0.0im
#                  3.0 + 0.0im
#                  3.0 + 0.0im
#                      ⋮
#                  2.8 + 0.0im
#                  2.8 + 0.0im
#  -1.1199999999999999 + 0.0im
#                -4.48 + 0.0im
#                  2.8 + 0.0im
#                  2.8 + 0.0im
#  -1.1199999999999999 + 0.0im
#                  2.0 + 0.0im
#                 -4.0 + 0.0im
#                  2.0 + 0.0im
#                 9.68 + 0.0im
#   1.6800000000000002 + 0.0im

# %%
monomials(obj)
# Out:
# 199-element MonomialVector{true}:
#  a₁₋₁⁴
#  a₁₋₁³a₂₋₂
#  a₁₋₁³b₂₋₁
#  a₁₋₁³b₁₋₂
#  a₁₋₁²a₂₋₁²
#  a₁₋₁²a₂₋₁a₁₋₂
#  a₁₋₁²a₂₋₁b₁₋₁
#  a₁₋₁²a₂₋₁b₂₋₂
#  a₁₋₁²a₁₋₂²
#  a₁₋₁²a₁₋₂b₁₋₁
#  a₁₋₁²a₁₋₂b₂₋₂
#  a₁₋₁²a₂₋₂²
#  a₁₋₁²a₂₋₂b₂₋₁
#  ⋮
#  x₄a₁₋₁a₁₋₂
#  x₄a₂₋₁a₂₋₂
#  x₄a₁₋₂a₂₋₂
#  x₄b₁₋₁b₂₋₁
#  x₄b₁₋₁b₁₋₂
#  x₄b₂₋₁b₂₋₂
#  x₄b₁₋₂b₂₋₂
#  x₁²
#  x₁x₂
#  x₂²
#  x₃²
#  x₄²

# %%
#real(coefficients(obj)[1])
obj2 = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
# Out:
# 0.5a₁₋₁⁴ - 2.0a₁₋₁³a₂₋₂ - a₁₋₁³b₂₋₁ - a₁₋₁³b₁₋₂ + 4.82a₁₋₁²a₂₋₁² - 3.4a₁₋₁²a₂₋₁a₁₋₂ + a₁₋₁²a₂₋₁b₁₋₁ - 3.0a₁₋₁²a₂₋₁b₂₋₂ + 3.0a₁₋₁²a₁₋₂² + a₁₋₁²a₁₋₂b₁₋₁ + a₁₋₁²a₁₋₂b₂₋₂ + 3.0a₁₋₁²a₂₋₂² + 3.0a₁₋₁²a₂₋₂b₂₋₁ + 3.0a₁₋₁²a₂₋₂b₁₋₂ + a₁₋₁²b₁₋₁² - 2.0a₁₋₁²b₁₋₁b₂₋₂ + 4.82a₁₋₁²b₂₋₁² + 7.3999999999999995a₁₋₁²b₂₋₁b₁₋₂ + 5.0a₁₋₁²b₁₋₂² + 3.0a₁₋₁²b₂₋₂² - 7.3999999999999995a₁₋₁a₂₋₁²a₂₋₂ - a₁₋₁a₂₋₁²b₂₋₁ - a₁₋₁a₂₋₁²b₁₋₂ + 3.16a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + 4.0a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 10.8a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + 7.16a₁₋₁a₂₋₁b₁₋₂b₂₋₂ - 4.6a₁₋₁a₁₋₂²a₂₋₂ - 3.0a₁₋₁a₁₋₂²b₂₋₁ - 3.0a₁₋₁a₁₋₂²b₁₋₂ - 4.0a₁₋₁a₁₋₂a₂₋₂b₁₋₁ - 10.8a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 4.0a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + 3.16a₁₋₁a₁₋₂b₂₋₁b₂₋₂ - 2.0a₁₋₁a₂₋₂³ - 3.0a₁₋₁a₂₋₂²b₂₋₁ - 3.0a₁₋₁a₂₋₂²b₁₋₂ - 2.0a₁₋₁a₂₋₂b₁₋₁² - 7.3999999999999995a₁₋₁a₂₋₂b₂₋₁² - 7.16a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 4.6a₁₋₁a₂₋₂b₁₋₂² - 2.0a₁₋₁a₂₋₂b₂₋₂² - a₁₋₁b₁₋₁²b₂₋₁ - a₁₋₁b₁₋₁²b₁₋₂ + 4.0a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - a₁₋₁b₂₋₁³ - a₁₋₁b₂₋₁²b₁₋₂ - 3.0a₁₋₁b₂₋₁b₁₋₂² + a₁₋₁b₂₋₁b₂₋₂² - 3.0a₁₋₁b₁₋₂³ - 3.0a₁₋₁b₁₋₂b₂₋₂² + 4.32a₂₋₁⁴ + 2.0a₂₋₁³a₁₋₂ + a₂₋₁³b₁₋₁ - 3.0a₂₋₁³b₂₋₂ - 0.15999999999999998a₂₋₁²a₁₋₂² + a₂₋₁²a₁₋₂b₁₋₁ - 3.0a₂₋₁²a₁₋₂b₂₋₂ + 3.0a₂₋₁²a₂₋₂² + 3.0a₂₋₁²a₂₋₂b₂₋₁ + 3.0a₂₋₁²a₂₋₂b₁₋₂ + 4.82a₂₋₁²b₁₋₁² - 7.3999999999999995a₂₋₁²b₁₋₁b₂₋₂ + 8.64a₂₋₁²b₂₋₁² + 2.0a₂₋₁²b₂₋₁b₁₋₂ - 0.15999999999999998a₂₋₁²b₁₋₂² + 5.0a₂₋₁²b₂₋₂² + 2.0a₂₋₁a₁₋₂³ + 3.0a₂₋₁a₁₋₂²b₁₋₁ - a₂₋₁a₁₋₂²b₂₋₂ - 0.6000000000000001a₂₋₁a₁₋₂a₂₋₂² + 7.3999999999999995a₂₋₁a₁₋₂b₁₋₁² - 7.16a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + 2.0a₂₋₁a₁₋₂b₂₋₁² + 2.0a₂₋₁a₁₋₂b₁₋₂² + 4.6a₂₋₁a₁₋₂b₂₋₂² - a₂₋₁a₂₋₂²b₁₋₁ - a₂₋₁a₂₋₂²b₂₋₂ + 3.16a₂₋₁a₂₋₂b₁₋₁b₁₋₂ - 4.0a₂₋₁a₂₋₂b₂₋₁b₂₋₂ - 5.2a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + a₂₋₁b₁₋₁³ - 3.0a₂₋₁b₁₋₁²b₂₋₂ + a₂₋₁b₁₋₁b₂₋₁² + 3.0a₂₋₁b₁₋₁b₁₋₂² + 3.0a₂₋₁b₁₋₁b₂₋₂² - 3.0a₂₋₁b₂₋₁²b₂₋₂ - a₂₋₁b₁₋₂²b₂₋₂ - a₂₋₁b₂₋₂³ + 1.52a₁₋₂⁴ + 3.0a₁₋₂³b₁₋₁ - a₁₋₂³b₂₋₂ + 2.02a₁₋₂²a₂₋₂² + a₁₋₂²a₂₋₂b₂₋₁ + a₁₋₂²a₂₋₂b₁₋₂ + 5.0a₁₋₂²b₁₋₁² - 4.6a₁₋₂²b₁₋₁b₂₋₂ - 0.15999999999999998a₁₋₂²b₂₋₁² + 2.0a₁₋₂²b₂₋₁b₁₋₂ + 3.04a₁₋₂²b₁₋₂² + 2.02a₁₋₂²b₂₋₂² + 3.0a₁₋₂a₂₋₂²b₁₋₁ - a₁₋₂a₂₋₂²b₂₋₂ + 7.16a₁₋₂a₂₋₂b₁₋₁b₂₋₁ - 5.2a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + a₁₋₂b₁₋₁³ - 3.0a₁₋₂b₁₋₁²b₂₋₂ + a₁₋₂b₁₋₁b₂₋₁² + 3.0a₁₋₂b₁₋₁b₁₋₂² + 3.0a₁₋₂b₁₋₁b₂₋₂² - 3.0a₁₋₂b₂₋₁²b₂₋₂ - a₁₋₂b₁₋₂²b₂₋₂ - a₁₋₂b₂₋₂³ + 0.5a₂₋₂⁴ + a₂₋₂³b₂₋₁ + a₂₋₂³b₁₋₂ + 3.0a₂₋₂²b₁₋₁² - 2.0a₂₋₂²b₁₋₁b₂₋₂ + 5.0a₂₋₂²b₂₋₁² + 4.6a₂₋₂²b₂₋₁b₁₋₂ + 2.02a₂₋₂²b₁₋₂² + a₂₋₂²b₂₋₂² + 3.0a₂₋₂b₁₋₁²b₂₋₁ - a₂₋₂b₁₋₁²b₁₋₂ - 4.0a₂₋₂b₁₋₁b₂₋₁b₂₋₂ + 3.0a₂₋₂b₂₋₁³ + 3.0a₂₋₂b₂₋₁²b₁₋₂ + a₂₋₂b₂₋₁b₁₋₂² + a₂₋₂b₂₋₁b₂₋₂² + a₂₋₂b₁₋₂³ + a₂₋₂b₁₋₂b₂₋₂² + 0.5b₁₋₁⁴ - 2.0b₁₋₁³b₂₋₂ + 4.82b₁₋₁²b₂₋₁² - 3.4b₁₋₁²b₂₋₁b₁₋₂ + 3.0b₁₋₁²b₁₋₂² + 3.0b₁₋₁²b₂₋₂² - 7.3999999999999995b₁₋₁b₂₋₁²b₂₋₂ + 3.16b₁₋₁b₂₋₁b₁₋₂b₂₋₂ - 4.6b₁₋₁b₁₋₂²b₂₋₂ - 2.0b₁₋₁b₂₋₂³ + 4.32b₂₋₁⁴ + 2.0b₂₋₁³b₁₋₂ - 0.15999999999999998b₂₋₁²b₁₋₂² + 3.0b₂₋₁²b₂₋₂² + 2.0b₂₋₁b₁₋₂³ - 0.6000000000000001b₂₋₁b₁₋₂b₂₋₂² + 1.52b₁₋₂⁴ + 2.02b₁₋₂²b₂₋₂² + 0.5b₂₋₂⁴ - 2.0x₁a₁₋₁a₂₋₁ + 2.0x₁a₁₋₁a₁₋₂ + 4.0x₁a₁₋₁b₂₋₂ + 2.0x₁a₂₋₁a₂₋₂ + 4.0x₁a₂₋₁b₁₋₂ - 2.0x₁a₁₋₂a₂₋₂ - 4.0x₁a₁₋₂b₂₋₁ - 4.0x₁a₂₋₂b₁₋₁ - 2.0x₁b₁₋₁b₂₋₁ + 2.0x₁b₁₋₁b₁₋₂ + 2.0x₁b₂₋₁b₂₋₂ - 2.0x₁b₁₋₂b₂₋₂ + 2.0x₂a₁₋₁a₂₋₁ - 2.0x₂a₁₋₁a₁₋₂ - 4.0x₂a₁₋₁b₂₋₂ - 2.0x₂a₂₋₁a₂₋₂ - 4.0x₂a₂₋₁b₁₋₂ + 2.0x₂a₁₋₂a₂₋₂ + 4.0x₂a₁₋₂b₂₋₁ + 4.0x₂a₂₋₂b₁₋₁ + 2.0x₂b₁₋₁b₂₋₁ - 2.0x₂b₁₋₁b₁₋₂ - 2.0x₂b₂₋₁b₂₋₂ + 2.0x₂b₁₋₂b₂₋₂ - 4.48x₃a₁₋₁b₂₋₁ - 10.8x₃a₁₋₁b₁₋₂ - 4.0x₃a₂₋₁² + 4.48x₃a₂₋₁b₁₋₁ + 5.199999999999999x₃a₂₋₁b₂₋₂ + 4.0x₃a₁₋₂² + 10.8x₃a₁₋₂b₁₋₁ - 1.1199999999999999x₃a₁₋₂b₂₋₂ - 5.199999999999999x₃a₂₋₂b₂₋₁ + 1.1199999999999999x₃a₂₋₂b₁₋₂ - 4.0x₃b₂₋₁² + 4.0x₃b₁₋₂² - 4.48x₄a₁₋₁a₂₋₁ + 2.8x₄a₁₋₁a₁₋₂ + 2.8x₄a₂₋₁a₂₋₂ - 1.1199999999999999x₄a₁₋₂a₂₋₂ - 4.48x₄b₁₋₁b₂₋₁ + 2.8x₄b₁₋₁b₁₋₂ + 2.8x₄b₂₋₁b₂₋₂ - 1.1199999999999999x₄b₁₋₂b₂₋₂ + 2.0x₁² - 4.0x₁x₂ + 2.0x₂² + 9.68x₃² + 1.6800000000000002x₄²

# %%
using TSSOS

opt,sol,data = tssos_first(obj2, variables(obj2))
# Out:
# ************************TSSOS************************
# TSSOS is launching...
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [22, 19, 1]
# [1, 1, 8]
# ------------------------------------------------------
# Obtained the block structure. The maximal size of blocks is 22.
# Assembling the SDP...
# There are 267 affine constraints.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 267
#   Cones                  : 0
#   Scalar variables       : 9
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 267
#   Cones                  : 0
#   Scalar variables       : 9
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 267
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 10                conic                  : 2
# Optimizer  - Semi-definite variables: 2                 scalarized             : 443
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.97e+04          after factor           : 2.97e+04
# Factor     - dense dim.             : 0                 flops                  : 4.45e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.1e+01  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   4.5e+00  4.2e-01  5.7e-01  -8.75e-01  -1.085458413e+00  -2.101676572e+00  4.2e-01  0.01
# 2   1.2e+00  1.1e-01  1.5e-01  -4.17e-01  -3.740320523e+00  -5.152996425e+00  1.1e-01  0.01
# 3   2.9e-01  2.7e-02  1.1e-02  8.57e-01   -6.627440243e-01  -7.528751710e-01  2.7e-02  0.01
# 4   8.5e-02  7.8e-03  1.8e-03  1.02e+00   -1.838940835e-01  -2.128362340e-01  7.8e-03  0.01
# 5   2.5e-02  2.3e-03  2.8e-04  1.06e+00   -8.385999029e-02  -9.258660987e-02  2.3e-03  0.01
# 6   8.4e-03  7.8e-04  6.2e-05  9.90e-01   -2.401998795e-02  -2.791853842e-02  7.8e-04  0.01
# 7   1.4e-03  1.3e-04  4.0e-06  1.20e+00   -8.336612943e-03  -8.901616415e-03  1.3e-04  0.01
# 8   5.3e-04  4.9e-05  9.3e-07  1.05e+00   -1.551903871e-03  -1.777425979e-03  4.9e-05  0.03
# 9   1.2e-04  1.2e-05  1.0e-07  9.72e-01   -3.571325257e-04  -4.058340662e-04  1.2e-05  0.03
# 10  3.3e-05  3.1e-06  1.5e-08  9.37e-01   -6.384041728e-05  -7.749832517e-05  3.1e-06  0.03
# 11  8.3e-06  7.7e-07  1.8e-09  9.65e-01   -3.511642192e-05  -3.814735299e-05  7.7e-07  0.03
# 12  1.9e-06  1.7e-07  1.9e-10  1.04e+00   -6.205354644e-06  -6.873970099e-06  1.7e-07  0.03
# 13  4.6e-07  4.3e-08  2.3e-11  9.81e-01   -1.333301182e-06  -1.506412732e-06  4.3e-08  0.03
# 14  1.2e-07  1.1e-08  3.0e-12  9.51e-01   -3.574332989e-07  -4.002598354e-07  1.1e-08  0.03
# 15  3.4e-08  3.0e-09  4.3e-13  9.27e-01   -9.400232010e-08  -1.060610828e-07  2.9e-09  0.03
# 16  1.1e-08  1.4e-09  7.7e-14  9.77e-01   -2.950934007e-08  -3.322322758e-08  9.2e-10  0.05
# Optimizer terminated. Time: 0.08
#
# SDP solving time: 0.076066 seconds.
# optimum = -2.9509340074434432e-8
# (-2.9509340074434432e-8, nothing, TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], 0.5a₁₋₁⁴ - 2.0a₁₋₁³a₂₋₂ - a₁₋₁³b₂₋₁ - a₁₋₁³b₁₋₂ + 4.82a₁₋₁²a₂₋₁² - 3.4a₁₋₁²a₂₋₁a₁₋₂ + a₁₋₁²a₂₋₁b₁₋₁ - 3.0a₁₋₁²a₂₋₁b₂₋₂ + 3.0a₁₋₁²a₁₋₂² + a₁₋₁²a₁₋₂b₁₋₁ + a₁₋₁²a₁₋₂b₂₋₂ + 3.0a₁₋₁²a₂₋₂² + 3.0a₁₋₁²a₂₋₂b₂₋₁ + 3.0a₁₋₁²a₂₋₂b₁₋₂ + a₁₋₁²b₁₋₁² - 2.0a₁₋₁²b₁₋₁b₂₋₂ + 4.82a₁₋₁²b₂₋₁² + 7.3999999999999995a₁₋₁²b₂₋₁b₁₋₂ + 5.0a₁₋₁²b₁₋₂² + 3.0a₁₋₁²b₂₋₂² - 7.3999999999999995a₁₋₁a₂₋₁²a₂₋₂ - a₁₋₁a₂₋₁²b₂₋₁ - a₁₋₁a₂₋₁²b₁₋₂ + 3.16a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + 4.0a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 10.8a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + 7.16a₁₋₁a₂₋₁b₁₋₂b₂₋₂ - 4.6a₁₋₁a₁₋₂²a₂₋₂ - 3.0a₁₋₁a₁₋₂²b₂₋₁ - 3.0a₁₋₁a₁₋₂²b₁₋₂ - 4.0a₁₋₁a₁₋₂a₂₋₂b₁₋₁ - 10.8a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 4.0a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + 3.16a₁₋₁a₁₋₂b₂₋₁b₂₋₂ - 2.0a₁₋₁a₂₋₂³ - 3.0a₁₋₁a₂₋₂²b₂₋₁ - 3.0a₁₋₁a₂₋₂²b₁₋₂ - 2.0a₁₋₁a₂₋₂b₁₋₁² - 7.3999999999999995a₁₋₁a₂₋₂b₂₋₁² - 7.16a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 4.6a₁₋₁a₂₋₂b₁₋₂² - 2.0a₁₋₁a₂₋₂b₂₋₂² - a₁₋₁b₁₋₁²b₂₋₁ - a₁₋₁b₁₋₁²b₁₋₂ + 4.0a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - a₁₋₁b₂₋₁³ - a₁₋₁b₂₋₁²b₁₋₂ - 3.0a₁₋₁b₂₋₁b₁₋₂² + a₁₋₁b₂₋₁b₂₋₂² - 3.0a₁₋₁b₁₋₂³ - 3.0a₁₋₁b₁₋₂b₂₋₂² + 4.32a₂₋₁⁴ + 2.0a₂₋₁³a₁₋₂ + a₂₋₁³b₁₋₁ - 3.0a₂₋₁³b₂₋₂ - 0.15999999999999998a₂₋₁²a₁₋₂² + a₂₋₁²a₁₋₂b₁₋₁ - 3.0a₂₋₁²a₁₋₂b₂₋₂ + 3.0a₂₋₁²a₂₋₂² + 3.0a₂₋₁²a₂₋₂b₂₋₁ + 3.0a₂₋₁²a₂₋₂b₁₋₂ + 4.82a₂₋₁²b₁₋₁² - 7.3999999999999995a₂₋₁²b₁₋₁b₂₋₂ + 8.64a₂₋₁²b₂₋₁² + 2.0a₂₋₁²b₂₋₁b₁₋₂ - 0.15999999999999998a₂₋₁²b₁₋₂² + 5.0a₂₋₁²b₂₋₂² + 2.0a₂₋₁a₁₋₂³ + 3.0a₂₋₁a₁₋₂²b₁₋₁ - a₂₋₁a₁₋₂²b₂₋₂ - 0.6000000000000001a₂₋₁a₁₋₂a₂₋₂² + 7.3999999999999995a₂₋₁a₁₋₂b₁₋₁² - 7.16a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + 2.0a₂₋₁a₁₋₂b₂₋₁² + 2.0a₂₋₁a₁₋₂b₁₋₂² + 4.6a₂₋₁a₁₋₂b₂₋₂² - a₂₋₁a₂₋₂²b₁₋₁ - a₂₋₁a₂₋₂²b₂₋₂ + 3.16a₂₋₁a₂₋₂b₁₋₁b₁₋₂ - 4.0a₂₋₁a₂₋₂b₂₋₁b₂₋₂ - 5.2a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + a₂₋₁b₁₋₁³ - 3.0a₂₋₁b₁₋₁²b₂₋₂ + a₂₋₁b₁₋₁b₂₋₁² + 3.0a₂₋₁b₁₋₁b₁₋₂² + 3.0a₂₋₁b₁₋₁b₂₋₂² - 3.0a₂₋₁b₂₋₁²b₂₋₂ - a₂₋₁b₁₋₂²b₂₋₂ - a₂₋₁b₂₋₂³ + 1.52a₁₋₂⁴ + 3.0a₁₋₂³b₁₋₁ - a₁₋₂³b₂₋₂ + 2.02a₁₋₂²a₂₋₂² + a₁₋₂²a₂₋₂b₂₋₁ + a₁₋₂²a₂₋₂b₁₋₂ + 5.0a₁₋₂²b₁₋₁² - 4.6a₁₋₂²b₁₋₁b₂₋₂ - 0.15999999999999998a₁₋₂²b₂₋₁² + 2.0a₁₋₂²b₂₋₁b₁₋₂ + 3.04a₁₋₂²b₁₋₂² + 2.02a₁₋₂²b₂₋₂² + 3.0a₁₋₂a₂₋₂²b₁₋₁ - a₁₋₂a₂₋₂²b₂₋₂ + 7.16a₁₋₂a₂₋₂b₁₋₁b₂₋₁ - 5.2a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + a₁₋₂b₁₋₁³ - 3.0a₁₋₂b₁₋₁²b₂₋₂ + a₁₋₂b₁₋₁b₂₋₁² + 3.0a₁₋₂b₁₋₁b₁₋₂² + 3.0a₁₋₂b₁₋₁b₂₋₂² - 3.0a₁₋₂b₂₋₁²b₂₋₂ - a₁₋₂b₁₋₂²b₂₋₂ - a₁₋₂b₂₋₂³ + 0.5a₂₋₂⁴ + a₂₋₂³b₂₋₁ + a₂₋₂³b₁₋₂ + 3.0a₂₋₂²b₁₋₁² - 2.0a₂₋₂²b₁₋₁b₂₋₂ + 5.0a₂₋₂²b₂₋₁² + 4.6a₂₋₂²b₂₋₁b₁₋₂ + 2.02a₂₋₂²b₁₋₂² + a₂₋₂²b₂₋₂² + 3.0a₂₋₂b₁₋₁²b₂₋₁ - a₂₋₂b₁₋₁²b₁₋₂ - 4.0a₂₋₂b₁₋₁b₂₋₁b₂₋₂ + 3.0a₂₋₂b₂₋₁³ + 3.0a₂₋₂b₂₋₁²b₁₋₂ + a₂₋₂b₂₋₁b₁₋₂² + a₂₋₂b₂₋₁b₂₋₂² + a₂₋₂b₁₋₂³ + a₂₋₂b₁₋₂b₂₋₂² + 0.5b₁₋₁⁴ - 2.0b₁₋₁³b₂₋₂ + 4.82b₁₋₁²b₂₋₁² - 3.4b₁₋₁²b₂₋₁b₁₋₂ + 3.0b₁₋₁²b₁₋₂² + 3.0b₁₋₁²b₂₋₂² - 7.3999999999999995b₁₋₁b₂₋₁²b₂₋₂ + 3.16b₁₋₁b₂₋₁b₁₋₂b₂₋₂ - 4.6b₁₋₁b₁₋₂²b₂₋₂ - 2.0b₁₋₁b₂₋₂³ + 4.32b₂₋₁⁴ + 2.0b₂₋₁³b₁₋₂ - 0.15999999999999998b₂₋₁²b₁₋₂² + 3.0b₂₋₁²b₂₋₂² + 2.0b₂₋₁b₁₋₂³ - 0.6000000000000001b₂₋₁b₁₋₂b₂₋₂² + 1.52b₁₋₂⁴ + 2.02b₁₋₂²b₂₋₂² + 0.5b₂₋₂⁴ - 2.0x₁a₁₋₁a₂₋₁ + 2.0x₁a₁₋₁a₁₋₂ + 4.0x₁a₁₋₁b₂₋₂ + 2.0x₁a₂₋₁a₂₋₂ + 4.0x₁a₂₋₁b₁₋₂ - 2.0x₁a₁₋₂a₂₋₂ - 4.0x₁a₁₋₂b₂₋₁ - 4.0x₁a₂₋₂b₁₋₁ - 2.0x₁b₁₋₁b₂₋₁ + 2.0x₁b₁₋₁b₁₋₂ + 2.0x₁b₂₋₁b₂₋₂ - 2.0x₁b₁₋₂b₂₋₂ + 2.0x₂a₁₋₁a₂₋₁ - 2.0x₂a₁₋₁a₁₋₂ - 4.0x₂a₁₋₁b₂₋₂ - 2.0x₂a₂₋₁a₂₋₂ - 4.0x₂a₂₋₁b₁₋₂ + 2.0x₂a₁₋₂a₂₋₂ + 4.0x₂a₁₋₂b₂₋₁ + 4.0x₂a₂₋₂b₁₋₁ + 2.0x₂b₁₋₁b₂₋₁ - 2.0x₂b₁₋₁b₁₋₂ - 2.0x₂b₂₋₁b₂₋₂ + 2.0x₂b₁₋₂b₂₋₂ - 4.48x₃a₁₋₁b₂₋₁ - 10.8x₃a₁₋₁b₁₋₂ - 4.0x₃a₂₋₁² + 4.48x₃a₂₋₁b₁₋₁ + 5.199999999999999x₃a₂₋₁b₂₋₂ + 4.0x₃a₁₋₂² + 10.8x₃a₁₋₂b₁₋₁ - 1.1199999999999999x₃a₁₋₂b₂₋₂ - 5.199999999999999x₃a₂₋₂b₂₋₁ + 1.1199999999999999x₃a₂₋₂b₁₋₂ - 4.0x₃b₂₋₁² + 4.0x₃b₁₋₂² - 4.48x₄a₁₋₁a₂₋₁ + 2.8x₄a₁₋₁a₁₋₂ + 2.8x₄a₂₋₁a₂₋₂ - 1.1199999999999999x₄a₁₋₂a₂₋₂ - 4.48x₄b₁₋₁b₂₋₁ + 2.8x₄b₁₋₁b₁₋₂ + 2.8x₄b₂₋₁b₂₋₂ - 1.1199999999999999x₄b₁₋₂b₂₋₂ + 2.0x₁² - 4.0x₁x₂ + 2.0x₂² + 9.68x₃² + 1.6800000000000002x₄², UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00], [0.5, -2.0, -1.0, -1.0, 4.82, -3.4, 1.0, -3.0, 3.0, 1.0  …  -4.48, 2.8, 2.8, -1.1199999999999999, 2.0, -4.0, 2.0, 9.68, 1.6800000000000002, 0.0], UInt8[0x00 0x0 ...

# %%
data
# Out:
# TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], (3.82 + 0.0im)a₁₋₁²a₂₋₁² + (-5.4 + 0.0im)a₁₋₁²a₂₋₁a₁₋₂ + (2.0 + 0.0im)a₁₋₁²a₁₋₂² + (3.82 + 0.0im)a₁₋₁²b₂₋₁² + (5.4 + 0.0im)a₁₋₁²b₂₋₁b₁₋₂ + (2.0 + 0.0im)a₁₋₁²b₁₋₂² + (-5.4 + 0.0im)a₁₋₁a₂₋₁²a₂₋₂ + (7.16 + 0.0im)a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + (-10.8 + 0.0im)a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + (7.16 + 0.0im)a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + (-2.6 + 0.0im)a₁₋₁a₁₋₂²a₂₋₂ + (-10.8 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₁ + (7.16 + 0.0im)a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + (-5.4 + 0.0im)a₁₋₁a₂₋₂b₂₋₁² + (-7.16 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₁₋₂ + (-2.6 + 0.0im)a₁₋₁a₂₋₂b₁₋₂² + (3.82 + 0.0im)a₂₋₁⁴ + (-3.1599999999999997 + 0.0im)a₂₋₁²a₁₋₂² + (2.0 + 0.0im)a₂₋₁²a₂₋₂² + (3.82 + 0.0im)a₂₋₁²b₁₋₁² + (-5.4 + 0.0im)a₂₋₁²b₁₋₁b₂₋₂ + (7.64 + 0.0im)a₂₋₁²b₂₋₁² + (-3.1599999999999997 + 0.0im)a₂₋₁²b₁₋₂² + (2.0 + 0.0im)a₂₋₁²b₂₋₂² + (-2.6 + 0.0im)a₂₋₁a₁₋₂a₂₋₂² + (5.4 + 0.0im)a₂₋₁a₁₋₂b₁₋₁² + (-7.16 + 0.0im)a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + (2.6 + 0.0im)a₂₋₁a₁₋₂b₂₋₂² + (7.16 + 0.0im)a₂₋₁a₂₋₂b₁₋₁b₁₋₂ + (-5.2 + 0.0im)a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + (1.02 + 0.0im)a₁₋₂⁴ + (1.02 + 0.0im)a₁₋₂²a₂₋₂² + (2.0 + 0.0im)a₁₋₂²b₁₋₁² + (-2.6 + 0.0im)a₁₋₂²b₁₋₁b₂₋₂ + (-3.1599999999999997 + 0.0im)a₁₋₂²b₂₋₁² + (2.04 + 0.0im)a₁₋₂²b₁₋₂² + (1.02 + 0.0im)a₁₋₂²b₂₋₂² + (7.16 + 0.0im)a₁₋₂a₂₋₂b₁₋₁b₂₋₁ + (-5.2 + 0.0im)a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + (2.0 + 0.0im)a₂₋₂²b₂₋₁² + (2.6 + 0.0im)a₂₋₂²b₂₋₁b₁₋₂ + (1.02 + 0.0im)a₂₋₂²b₁₋₂² + (3.82 + 0.0im)b₁₋₁²b₂₋₁² + (-5.4 + 0.0im)b₁₋₁²b₂₋₁b₁₋₂ + (2.0 + 0.0im)b₁₋₁²b₁₋₂² + (-5.4 + 0.0im)b₁₋₁b₂₋₁²b₂₋₂ + (7.16 + 0.0im)b₁₋₁b₂₋₁b₁₋₂b₂₋₂ + (-2.6 + 0.0im)b₁₋₁b₁₋₂²b₂₋₂ + (3.82 + 0.0im)b₂₋₁⁴ + (-3.1599999999999997 + 0.0im)b₂₋₁²b₁₋₂² + (2.0 + 0.0im)b₂₋₁²b₂₋₂² + (-2.6 + 0.0im)b₂₋₁b₁₋₂b₂₋₂² + (1.02 + 0.0im)b₁₋₂⁴ + (1.02 + 0.0im)b₁₋₂²b₂₋₂² + (-4.48 + 0.0im)x₃a₁₋₁b₂₋₁ + (-2.8 + 0.0im)x₃a₁₋₁b₁₋₂ + (4.48 + 0.0im)x₃a₂₋₁b₁₋₁ + (-2.8 + 0.0im)x₃a₂₋₁b₂₋₂ + (2.8 + 0.0im)x₃a₁₋₂b₁₋₁ + (-1.1199999999999999 + 0.0im)x₃a₁₋₂b₂₋₂ + (2.8 + 0.0im)x₃a₂₋₂b₂₋₁ + (1.1199999999999999 + 0.0im)x₃a₂₋₂b₁₋₂ + (-4.48 + 0.0im)x₄a₁₋₁a₂₋₁ + (2.8 + 0.0im)x₄a₁₋₁a₁₋₂ + (2.8 + 0.0im)x₄a₂₋₁a₂₋₂ + (-1.1199999999999999 + 0.0im)x₄a₁₋₂a₂₋₂ + (-4.48 + 0.0im)x₄b₁₋₁b₂₋₁ + (2.8 + 0.0im)x₄b₁₋₁b₁₋₂ + (2.8 + 0.0im)x₄b₂₋₁b₂₋₂ + (-1.1199999999999999 + 0.0im)x₄b₁₋₂b₂₋₂ + (1.6800000000000002 + 0.0im)x₃² + (1.6800000000000002 + 0.0im)x₄², UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00], ComplexF64[3.82 + 0.0im, -5.4 + 0.0im, 2.0 + 0.0im, 3.82 + 0.0im, 5.4 + 0.0im, 2.0 + 0.0im, -5.4 + 0.0im, 7.16 + 0.0im, -10.8 + 0.0im, 7.16 + 0.0im  …  2.8 + 0.0im, 2.8 + 0.0im, -1.1199999999999999 + 0.0im, -4.48 + 0.0im, 2.8 + 0.0im, 2.8 + 0.0im, -1.1199999999999999 + 0.0im, 1.6800000000000002 + 0.0im, 1.6800000000000002 + 0.0im, 0.0 + 0.0im], UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00 … 0x00 0x01; 0x00 0x00 … 0x01 0x01], UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x02 … 0x00 0x00; 0x00 0x00 … 0x00 0x00], [[1, 9, 12, 22, 29], [2, 15, 16, 17, 20, 23, 26, 30, 31], [3, 8, 10, 13, 14, 21, 27, 32, 33], [4], [5], [6], [7], [11], [18], [19], [24], [25], [28]], [9, 5, 1], [2, 1, 10], nothing, "Mosek", 0.0001, 1)

# %%
opt,sol,data = tssos_higher!(data)
# Out:
# Starting to compute the block structure...
# No higher TSSOS hierarchy!
# (nothing, nothing, TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], (3.82 + 0.0im)a₁₋₁²a₂₋₁² + (-5.4 + 0.0im)a₁₋₁²a₂₋₁a₁₋₂ + (2.0 + 0.0im)a₁₋₁²a₁₋₂² + (3.82 + 0.0im)a₁₋₁²b₂₋₁² + (5.4 + 0.0im)a₁₋₁²b₂₋₁b₁₋₂ + (2.0 + 0.0im)a₁₋₁²b₁₋₂² + (-5.4 + 0.0im)a₁₋₁a₂₋₁²a₂₋₂ + (7.16 + 0.0im)a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + (-10.8 + 0.0im)a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + (7.16 + 0.0im)a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + (-2.6 + 0.0im)a₁₋₁a₁₋₂²a₂₋₂ + (-10.8 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₁ + (7.16 + 0.0im)a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + (-5.4 + 0.0im)a₁₋₁a₂₋₂b₂₋₁² + (-7.16 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₁₋₂ + (-2.6 + 0.0im)a₁₋₁a₂₋₂b₁₋₂² + (3.82 + 0.0im)a₂₋₁⁴ + (-3.1599999999999997 + 0.0im)a₂₋₁²a₁₋₂² + (2.0 + 0.0im)a₂₋₁²a₂₋₂² + (3.82 + 0.0im)a₂₋₁²b₁₋₁² + (-5.4 + 0.0im)a₂₋₁²b₁₋₁b₂₋₂ + (7.64 + 0.0im)a₂₋₁²b₂₋₁² + (-3.1599999999999997 + 0.0im)a₂₋₁²b₁₋₂² + (2.0 + 0.0im)a₂₋₁²b₂₋₂² + (-2.6 + 0.0im)a₂₋₁a₁₋₂a₂₋₂² + (5.4 + 0.0im)a₂₋₁a₁₋₂b₁₋₁² + (-7.16 + 0.0im)a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + (2.6 + 0.0im)a₂₋₁a₁₋₂b₂₋₂² + (7.16 + 0.0im)a₂₋₁a₂₋₂b₁₋₁b₁₋₂ + (-5.2 + 0.0im)a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + (1.02 + 0.0im)a₁₋₂⁴ + (1.02 + 0.0im)a₁₋₂²a₂₋₂² + (2.0 + 0.0im)a₁₋₂²b₁₋₁² + (-2.6 + 0.0im)a₁₋₂²b₁₋₁b₂₋₂ + (-3.1599999999999997 + 0.0im)a₁₋₂²b₂₋₁² + (2.04 + 0.0im)a₁₋₂²b₁₋₂² + (1.02 + 0.0im)a₁₋₂²b₂₋₂² + (7.16 + 0.0im)a₁₋₂a₂₋₂b₁₋₁b₂₋₁ + (-5.2 + 0.0im)a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + (2.0 + 0.0im)a₂₋₂²b₂₋₁² + (2.6 + 0.0im)a₂₋₂²b₂₋₁b₁₋₂ + (1.02 + 0.0im)a₂₋₂²b₁₋₂² + (3.82 + 0.0im)b₁₋₁²b₂₋₁² + (-5.4 + 0.0im)b₁₋₁²b₂₋₁b₁₋₂ + (2.0 + 0.0im)b₁₋₁²b₁₋₂² + (-5.4 + 0.0im)b₁₋₁b₂₋₁²b₂₋₂ + (7.16 + 0.0im)b₁₋₁b₂₋₁b₁₋₂b₂₋₂ + (-2.6 + 0.0im)b₁₋₁b₁₋₂²b₂₋₂ + (3.82 + 0.0im)b₂₋₁⁴ + (-3.1599999999999997 + 0.0im)b₂₋₁²b₁₋₂² + (2.0 + 0.0im)b₂₋₁²b₂₋₂² + (-2.6 + 0.0im)b₂₋₁b₁₋₂b₂₋₂² + (1.02 + 0.0im)b₁₋₂⁴ + (1.02 + 0.0im)b₁₋₂²b₂₋₂² + (-4.48 + 0.0im)x₃a₁₋₁b₂₋₁ + (-2.8 + 0.0im)x₃a₁₋₁b₁₋₂ + (4.48 + 0.0im)x₃a₂₋₁b₁₋₁ + (-2.8 + 0.0im)x₃a₂₋₁b₂₋₂ + (2.8 + 0.0im)x₃a₁₋₂b₁₋₁ + (-1.1199999999999999 + 0.0im)x₃a₁₋₂b₂₋₂ + (2.8 + 0.0im)x₃a₂₋₂b₂₋₁ + (1.1199999999999999 + 0.0im)x₃a₂₋₂b₁₋₂ + (-4.48 + 0.0im)x₄a₁₋₁a₂₋₁ + (2.8 + 0.0im)x₄a₁₋₁a₁₋₂ + (2.8 + 0.0im)x₄a₂₋₁a₂₋₂ + (-1.1199999999999999 + 0.0im)x₄a₁₋₂a₂₋₂ + (-4.48 + 0.0im)x₄b₁₋₁b₂₋₁ + (2.8 + 0.0im)x₄b₁₋₁b₁₋₂ + (2.8 + 0.0im)x₄b₂₋₁b₂₋₂ + (-1.1199999999999999 + 0.0im)x₄b₁₋₂b₂₋₂ + (1.6800000000000002 + 0.0im)x₃² + (1.6800000000000002 + 0.0im)x₄², UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00], ComplexF64[3.82 + 0.0im, -5.4 + 0.0im, 2.0 + 0.0im, 3.82 + 0.0im, 5.4 + 0.0im, 2.0 + 0.0im, -5.4 + 0.0im, 7.16 + 0.0im, -10.8 + 0.0im, 7.16 + 0.0im  …  2.8 + 0.0im, 2.8 + 0.0im, -1.1199999999999999 + 0.0im, -4.48 + 0.0im, 2.8 + 0.0im, 2.8 + 0.0im, -1.1199999999999999 + 0.0im, 1.6800000000000002 + 0.0im, 1.6800000000000002 + 0.0im, 0.0 + 0.0im], UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00 … 0x00 0x01; 0x00 0x00 … 0x01 0x01], UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x02 … 0x00 0x00; 0x00 0x00 … 0x00 0x00], [[1, 9, 12, 22, 29], [2, 15, 16, 17, 20, 23, 26, 30, 31], [3, 8, 10, 13, 14, 21, 27, 32, 33], [4], [5], [6], [7], [11], [18], [19], [24], [25], [28]], [9, 5, 1], [2, 1, 10], nothing, "Mosek", 0.0001, 1))

# %%
data
# Out:
# TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], 3.9013984560897357a₁₋₁⁴ - 6.8275060551687385a₁₋₁³a₂₋₁ + 7.149253186027157a₁₋₁³a₁₋₂ - 15.605593824358943a₁₋₁³a₂₋₂ - 15.836285113303198a₁₋₁³b₂₋₁ - 17.742161423756077a₁₋₁³b₁₋₂ + 27.631079865289387a₁₋₁²a₂₋₁² - 31.909351963306776a₁₋₁²a₂₋₁a₁₋₂ + 20.804265296364633a₁₋₁²a₂₋₁a₂₋₂ + 15.836285113303198a₁₋₁²a₂₋₁b₁₋₁ + 10.560669369472265a₁₋₁²a₂₋₁b₁₋₂ - 49.41473165036247a₁₋₁²a₂₋₁b₂₋₂ + 35.25510180274852a₁₋₁²a₁₋₂² - 21.769506688939884a₁₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₁₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₂₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₁₋₂ + 15.8362851133032a₁₋₁²a₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²a₂₋₂² + 49.41473165036247a₁₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₁₋₁²a₂₋₂b₁₋₂ + 7.802796912179471a₁₋₁²b₁₋₁² - 6.8275060551687385a₁₋₁²b₁₋₁b₂₋₁ + 7.149253186027157a₁₋₁²b₁₋₁b₁₋₂ - 15.605593824358943a₁₋₁²b₁₋₁b₂₋₂ + 27.631079865289387a₁₋₁²b₂₋₁² + 53.31132004974846a₁₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₁₋₁²b₂₋₁b₂₋₂ + 45.956085845969355a₁₋₁²b₁₋₂² + 6.8275060551687385a₁₋₁²b₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²b₂₋₂² - 6.8275060551687385a₁₋₁a₂₋₁³ + 7.149253186027158a₁₋₁a₂₋₁²a₁₋₂ - 58.21592983088656a₁₋₁a₂₋₁²a₂₋₂ - 15.836285113303198a₁₋₁a₂₋₁²b₂₋₁ - 17.742161423756077a₁₋₁a₂₋₁²b₁₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₁₋₂² + 69.2575282392556a₁₋₁a₂₋₁a₁₋₂a₂₋₂ - 10.560669369472265a₁₋₁a₂₋₁a₁₋₂b₂₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₂₋₂² - 10.560669369472265a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + 70.9686456950243a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₁₋₁² - 85.22067201305524a₁₋₁a₂₋₁b₁₋₁b₁₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₂₋₁² - 21.126012427223053a₁₋₁a₂₋₁b₁₋₂² + 90.65949632569733a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + 7.471000316885574a₁₋₁a₂₋₁b₂₋₂² + 22.0912538197983a₁₋₁a₁₋₂³ - 72.99525781783133a₁₋₁a₁₋₂²a₂₋₂ + 10.560669369472265a₁₋₁a₁₋₂²b₁₋₁ - 51.32060796081537a₁₋₁a₁₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₁₋₂²b₁₋₂ + 22.0912538197983a₁₋₁a₁₋₂a₂₋₂² - 70.9686456950243a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + 10.560669369472265a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + 7.149253186027157a₁₋₁a₁₋₂b₁₋₁² - 85.22067201305524a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 21.40196808644169a₁₋₁a₁₋₂b₁₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + 7.149253186027158a₁₋₁a₁₋₂b₂₋₁² + 69.2575282392556a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + 22.0912538197983a₁₋₁a₁₋₂b₁₋₂² + 22.0912538197983a₁₋₁a₁₋₂b₂₋₂² - 15.605593824358943a₁₋₁a₂₋₂³ - 51.320607960815366a₁₋₁a₂₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₂₋₂²b₁₋₂ - 15.605593824358943a₁₋₁a₂₋₂b₁₋₁² - 28.59701274410863a₁₋₁a₂₋₂b₁₋₁b₁₋₂ - 58.21592983088656a₁₋₁a₂₋₂b₂₋₁² - 90.65949632569735a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₂₋₂b₂₋₁b₂₋₂ - 72.99525781783133a₁₋₁a₂₋₂b₁₋₂² - 15.605593824358943a₁₋₁a₂₋₂b₂₋₂² - 15.836285113303198a₁₋₁b₁₋₁²b₂₋₁ - 17.742161423756077a₁₋₁b₁₋₁²b₁₋₂ - 10.560669369472265a₁₋₁b₁₋₁b₁₋₂² + 70.9686456950243a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 15.836285113303198a₁₋₁b₂₋₁³ - 17.742161423756077a₁₋₁b₂₋₁²b₁₋₂ - 51.32060796081537a₁₋₁b₂₋₁b₁₋₂² - 10.560669369472265a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + 19.648037734208966a₁₋₁b₂₋₁b₂₋₂² - 57.03823689217399a₁₋₁b₁₋₂³ - 57.03823689217399a₁₋₁b₁₋₂b₂₋₂² + 23.729681409199653a₂₋₁⁴ + 10.700984043220846a₂₋₁³a₁₋₂ + 20.804265296364633a₂₋₁³a₂₋₂ + 15.836285113303198a₂₋₁³b₁₋₁ + 10.560669369472265a₂₋₁³b₁₋₂ - 49.41473165036247a₂₋₁³b₂₋₂ - 22.155715370297a₂₋₁²a₁₋₂² - 21.769506688939884a₂₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₂₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₂₋₁²a₁₋₂b₂₋₁ - 55.13236058172113a₂₋₁²a₁₋₂b₂₋₂ + 35.25510180274852a₂₋₁²a₂₋₂² + 49.41473165036247a₂₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₂₋₁²a₂₋₂b₁₋₂ - 10.560669369472265a₂₋₁²a₂₋₂b₂₋₂ + 27.631079865289387a₂₋₁²b₁₋₁² - 6.8275060551687385a₂₋₁²b₁₋₁b₂₋₁ + 7.149253186027158a₂₋₁²b₁₋₁b₁₋₂ - 58.21592983088656a₂₋₁²b₁₋₁b₂₋₂ + 47.459362818399306a₂₋₁²b₂₋₁² + 10.700984043220846a₂₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₂₋₁²b₂₋₁b₂₋₂ - 22.155715370297a₂₋₁²b₁₋₂² - 21.769506688939884a₂₋₁²b₁₋₂b₂₋₂ + 45.956085845969355a₂₋₁²b₂₋₂² + 10.700984043220846a₂₋₁a₁₋₂³ + 7.149253186027157a₂₋₁a₁₋₂²a₂₋₂ + 51.32060796081537a₂₋₁a₁₋₂²b₁₋₁ + 10.560669369472265a₂₋₁a₁₋₂²b₁₋₂ - 17.74216142375608a₂₋₁a₁₋₂²b₂₋₂ - 46.68867995025157a₂₋₁a₁₋₂a₂₋₂² + 10.560669369472265a₂₋₁a₁₋₂a₂₋₂b₁₋₁ + 53.31132004974846a₂₋₁a₁₋₂b₁₋₁² - 90.65949632569735a₂₋₁ ...

# %%
using HDF5
# vars = vcat(x, vec(a), vec(b))

# %%
fname="time_series_lindblad_rnd_rho_2022-04-27_03-35-20.hdf5"
file = h5open(fname, "r")
dset = file["0.0"]["1000923797"]["rho"]
ρ_series = read(dset)

obj_ser = frobenius_norm2(lindblad_rhs(ρ_series[:, :, 1]))

println(size(ρ_series,3))

for i in 2:size(ρ_series,3)
    obj_ser += frobenius_norm2(lindblad_rhs(ρ_series[:, :, i]))
end

obj_ser2 = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj_ser), monomials(obj_ser)))
# Out:
# 50
# 3.9013984560897357a₁₋₁⁴ - 6.8275060551687385a₁₋₁³a₂₋₁ + 7.149253186027157a₁₋₁³a₁₋₂ - 15.605593824358943a₁₋₁³a₂₋₂ - 15.836285113303198a₁₋₁³b₂₋₁ - 17.742161423756077a₁₋₁³b₁₋₂ + 27.631079865289387a₁₋₁²a₂₋₁² - 31.909351963306776a₁₋₁²a₂₋₁a₁₋₂ + 20.804265296364633a₁₋₁²a₂₋₁a₂₋₂ + 15.836285113303198a₁₋₁²a₂₋₁b₁₋₁ + 10.560669369472265a₁₋₁²a₂₋₁b₁₋₂ - 49.41473165036247a₁₋₁²a₂₋₁b₂₋₂ + 35.25510180274852a₁₋₁²a₁₋₂² - 21.769506688939884a₁₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₁₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₂₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₁₋₂ + 15.8362851133032a₁₋₁²a₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²a₂₋₂² + 49.41473165036247a₁₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₁₋₁²a₂₋₂b₁₋₂ + 7.802796912179471a₁₋₁²b₁₋₁² - 6.8275060551687385a₁₋₁²b₁₋₁b₂₋₁ + 7.149253186027157a₁₋₁²b₁₋₁b₁₋₂ - 15.605593824358943a₁₋₁²b₁₋₁b₂₋₂ + 27.631079865289387a₁₋₁²b₂₋₁² + 53.31132004974846a₁₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₁₋₁²b₂₋₁b₂₋₂ + 45.956085845969355a₁₋₁²b₁₋₂² + 6.8275060551687385a₁₋₁²b₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²b₂₋₂² - 6.8275060551687385a₁₋₁a₂₋₁³ + 7.149253186027158a₁₋₁a₂₋₁²a₁₋₂ - 58.21592983088656a₁₋₁a₂₋₁²a₂₋₂ - 15.836285113303198a₁₋₁a₂₋₁²b₂₋₁ - 17.742161423756077a₁₋₁a₂₋₁²b₁₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₁₋₂² + 69.2575282392556a₁₋₁a₂₋₁a₁₋₂a₂₋₂ - 10.560669369472265a₁₋₁a₂₋₁a₁₋₂b₂₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₂₋₂² - 10.560669369472265a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + 70.9686456950243a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₁₋₁² - 85.22067201305524a₁₋₁a₂₋₁b₁₋₁b₁₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₂₋₁² - 21.126012427223053a₁₋₁a₂₋₁b₁₋₂² + 90.65949632569733a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + 7.471000316885574a₁₋₁a₂₋₁b₂₋₂² + 22.0912538197983a₁₋₁a₁₋₂³ - 72.99525781783133a₁₋₁a₁₋₂²a₂₋₂ + 10.560669369472265a₁₋₁a₁₋₂²b₁₋₁ - 51.32060796081537a₁₋₁a₁₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₁₋₂²b₁₋₂ + 22.0912538197983a₁₋₁a₁₋₂a₂₋₂² - 70.9686456950243a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + 10.560669369472265a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + 7.149253186027157a₁₋₁a₁₋₂b₁₋₁² - 85.22067201305524a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 21.40196808644169a₁₋₁a₁₋₂b₁₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + 7.149253186027158a₁₋₁a₁₋₂b₂₋₁² + 69.2575282392556a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + 22.0912538197983a₁₋₁a₁₋₂b₁₋₂² + 22.0912538197983a₁₋₁a₁₋₂b₂₋₂² - 15.605593824358943a₁₋₁a₂₋₂³ - 51.320607960815366a₁₋₁a₂₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₂₋₂²b₁₋₂ - 15.605593824358943a₁₋₁a₂₋₂b₁₋₁² - 28.59701274410863a₁₋₁a₂₋₂b₁₋₁b₁₋₂ - 58.21592983088656a₁₋₁a₂₋₂b₂₋₁² - 90.65949632569735a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₂₋₂b₂₋₁b₂₋₂ - 72.99525781783133a₁₋₁a₂₋₂b₁₋₂² - 15.605593824358943a₁₋₁a₂₋₂b₂₋₂² - 15.836285113303198a₁₋₁b₁₋₁²b₂₋₁ - 17.742161423756077a₁₋₁b₁₋₁²b₁₋₂ - 10.560669369472265a₁₋₁b₁₋₁b₁₋₂² + 70.9686456950243a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 15.836285113303198a₁₋₁b₂₋₁³ - 17.742161423756077a₁₋₁b₂₋₁²b₁₋₂ - 51.32060796081537a₁₋₁b₂₋₁b₁₋₂² - 10.560669369472265a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + 19.648037734208966a₁₋₁b₂₋₁b₂₋₂² - 57.03823689217399a₁₋₁b₁₋₂³ - 57.03823689217399a₁₋₁b₁₋₂b₂₋₂² + 23.729681409199653a₂₋₁⁴ + 10.700984043220846a₂₋₁³a₁₋₂ + 20.804265296364633a₂₋₁³a₂₋₂ + 15.836285113303198a₂₋₁³b₁₋₁ + 10.560669369472265a₂₋₁³b₁₋₂ - 49.41473165036247a₂₋₁³b₂₋₂ - 22.155715370297a₂₋₁²a₁₋₂² - 21.769506688939884a₂₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₂₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₂₋₁²a₁₋₂b₂₋₁ - 55.13236058172113a₂₋₁²a₁₋₂b₂₋₂ + 35.25510180274852a₂₋₁²a₂₋₂² + 49.41473165036247a₂₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₂₋₁²a₂₋₂b₁₋₂ - 10.560669369472265a₂₋₁²a₂₋₂b₂₋₂ + 27.631079865289387a₂₋₁²b₁₋₁² - 6.8275060551687385a₂₋₁²b₁₋₁b₂₋₁ + 7.149253186027158a₂₋₁²b₁₋₁b₁₋₂ - 58.21592983088656a₂₋₁²b₁₋₁b₂₋₂ + 47.459362818399306a₂₋₁²b₂₋₁² + 10.700984043220846a₂₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₂₋₁²b₂₋₁b₂₋₂ - 22.155715370297a₂₋₁²b₁₋₂² - 21.769506688939884a₂₋₁²b₁₋₂b₂₋₂ + 45.956085845969355a₂₋₁²b₂₋₂² + 10.700984043220846a₂₋₁a₁₋₂³ + 7.149253186027157a₂₋₁a₁₋₂²a₂₋₂ + 51.32060796081537a₂₋₁a₁₋₂²b₁₋₁ + 10.560669369472265a₂₋₁a₁₋₂²b₁₋₂ - 17.74216142375608a₂₋₁a₁₋₂²b₂₋₂ - 46.68867995025157a₂₋₁a₁₋₂a₂₋₂² + 10.560669369472265a₂₋₁a₁₋₂a₂₋₂b₁₋₁ + 53.31132004974846a₂₋₁a₁₋₂b₁₋₁² - 90.65949632569735a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + 10.700984043220846a₂₋₁a₁₋₂b₂₋₁² + 10.700984043220846a₂₋₁a₁₋₂b₁₋₂² + 68.09064803669321a₂ ...

# %%
q = setdiff(Set(monomials(obj_ser)), Set(monomials(obj_ser2)))
# Out:
# Set{Monomial{true}} with 8 elements:
#   a₁₋₁a₁₋₂²b₂₋₂
#   a₂₋₂b₁₋₁b₂₋₁²
#   a₁₋₁b₂₋₁²b₂₋₂
#   a₁₋₁b₁₋₂²b₂₋₂
#   a₂₋₂b₁₋₁b₁₋₂²
#   a₁₋₂²a₂₋₂b₁₋₁
#   a₂₋₁²a₂₋₂b₁₋₁
#   a₁₋₁a₂₋₁²b₂₋₂

# %%
[coefficient(x, obj_ser) for x in q]
# Out:
# MethodError: no method matching coefficient(::Monomial{true}, ::Polynomial{true, ComplexF64})
# Closest candidates are:
#   coefficient(::AbstractMonomialLike) at C:\Users\Zakhar\.julia\packages\MultivariatePolynomials\vqcb5\src\term.jl:71
#   coefficient(::AbstractPolynomialLike{T}, ::AbstractMonomialLike) where T at C:\Users\Zakhar\.julia\packages\MultivariatePolynomials\vqcb5\src\term.jl:72
#   coefficient(::AbstractPolynomialLike, ::AbstractMonomialLike, ::Any) at C:\Users\Zakhar\.julia\packages\MultivariatePolynomials\vqcb5\src\term.jl:91
#
# Stacktrace:
#  [1] (::var"#19#20")(x::Monomial{true})
#    @ Main .\none:0
#  [2] iterate
#    @ .\generator.jl:47 [inlined]
#  [3] collect(itr::Base.Generator{Set{Monomial{true}}, var"#19#20"})
#    @ Base .\array.jl:724
#  [4] top-level scope
#    @ In[85]:1
#  [5] eval
#    @ .\boot.jl:373 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
terms(obj_ser2 - obj_ser)
# Out:
# 49-element DynamicPolynomials.TermIterator{true, ComplexF64}:
#  (0.0 - 7.28583859910259e-17im)a₁₋₁²a₁₋₂b₂₋₂
#  (0.0 - 8.088148206741863e-17im)a₁₋₁²a₂₋₂b₂₋₁
#  (0.0 + 7.28583859910259e-17im)a₁₋₁²a₂₋₂b₁₋₂
#  (0.0 - 8.326672684688674e-17im)a₁₋₁²b₁₋₂b₂₋₂
#  (0.0 + 1.0842021724855044e-19im)a₁₋₁a₂₋₁²b₁₋₂
#  (-0.0 - 2.7755575615628914e-17im)a₁₋₁a₂₋₁²b₂₋₂
#  (0.0 + 1.8041124150158794e-16im)a₁₋₁a₂₋₁b₂₋₂²
#  (0.0 + 6.938893903907228e-18im)a₁₋₁a₁₋₂²b₂₋₁
#  (-0.0 - 2.7755575615628914e-17im)a₁₋₁a₁₋₂²b₂₋₂
#  (0.0 + 1.3877787807814457e-17im)a₁₋₁a₁₋₂a₂₋₂²
#  (0.0 + 1.3877787807814457e-17im)a₁₋₁a₁₋₂b₂₋₂²
#  (0.0 + 8.673617379884035e-18im)a₁₋₁a₂₋₂²b₂₋₁
#  (0.0 - 6.071532165918825e-18im)a₁₋₁a₂₋₂²b₁₋₂
#  ⋮
#  (0.0 + 4.85722573273506e-17im)a₁₋₂b₁₋₁²b₂₋₂
#  (0.0 + 1.6241348543832856e-16im)a₁₋₂b₁₋₁b₂₋₁²
#  (0.0 - 3.946495907847236e-17im)a₁₋₂b₁₋₁b₂₋₂²
#  (0.0 + 6.938893903907228e-18im)a₁₋₂b₂₋₁²b₂₋₂
#  (0.0 + 8.326672684688674e-17im)a₂₋₂²b₁₋₁b₁₋₂
#  (0.0 + 1.0842021724855044e-19im)a₂₋₂b₁₋₁²b₂₋₁
#  (0.0 - 4.85722573273506e-17im)a₂₋₂b₁₋₁²b₁₋₂
#  (-0.0 - 1.3877787807814457e-17im)a₂₋₂b₁₋₁b₂₋₁²
#  (-0.0 - 1.249000902703301e-16im)a₂₋₂b₁₋₁b₁₋₂²
#  (0.0 - 8.239936510889834e-18im)a₂₋₂b₂₋₁b₁₋₂²
#  (0.0 + 1.3877787807814457e-17im)b₁₋₁b₁₋₂b₂₋₂²
#  (0.0 + 1.3877787807814457e-16im)b₂₋₁b₁₋₂²b₂₋₂

# %%
println(nterms(simplify(obj_ser)))
# Out:
# 368

# %%
#using TSSOS
#using DynamicPolynomials

opt,sol,data = tssos_first(obj_ser2, variables(obj_ser2))
# Out:
# ************************TSSOS************************
# TSSOS is launching...
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [41, 1]
# [1, 8]
# ------------------------------------------------------
# Obtained the block structure. The maximal size of blocks is 41.
# Assembling the SDP...
# There are 525 affine constraints.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 525
#   Cones                  : 0
#   Scalar variables       : 9
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 525
#   Cones                  : 0
#   Scalar variables       : 9
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 525
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 10                conic                  : 2
# Optimizer  - Semi-definite variables: 1                 scalarized             : 861
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.38e+05          after factor           : 1.38e+05
# Factor     - dense dim.             : 0                 flops                  : 5.04e+07
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.1e+02  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   4.6e+01  4.0e-01  6.3e-01  -9.92e-01  -1.720059765e+00  -3.151295684e+00  4.0e-01  0.08
# 2   1.0e+01  8.8e-02  2.7e-01  -9.62e-01  -3.130866176e+01  -3.983068563e+01  8.8e-02  0.08
# 3   2.2e+00  1.9e-02  6.0e-02  -5.65e-01  -4.481794067e+01  -5.436128454e+01  1.9e-02  0.09
# 4   5.2e-01  4.5e-03  6.7e-03  6.24e-01   -1.102287255e+01  -1.308268364e+01  4.5e-03  0.09
# 5   7.4e-02  6.5e-04  3.4e-04  9.35e-01   -1.621528760e+00  -1.886195557e+00  6.5e-04  0.11
# 6   1.1e-02  9.7e-05  1.9e-05  9.87e-01   -2.468536459e-01  -2.822276394e-01  9.7e-05  0.13
# 7   2.0e-03  1.8e-05  1.5e-06  1.01e+00   -5.210991389e-02  -5.898432658e-02  1.8e-05  0.13
# 8   4.1e-04  3.6e-06  1.4e-07  9.96e-01   -1.034768370e-02  -1.178202178e-02  3.6e-06  0.14
# 9   8.9e-05  7.8e-07  1.4e-08  9.47e-01   -2.184297998e-03  -2.484923900e-03  7.8e-07  0.14
# 10  1.7e-05  1.5e-07  1.1e-09  9.30e-01   -4.331232598e-04  -4.852097551e-04  1.5e-07  0.16
# 11  3.6e-06  3.1e-08  1.1e-10  1.00e+00   -1.018401422e-04  -1.139853805e-04  3.1e-08  0.16
# 12  6.5e-07  5.9e-09  9.5e-12  1.08e+00   -2.099838824e-05  -2.343126663e-05  5.9e-09  0.17
# 13  9.4e-08  8.8e-10  5.5e-13  1.10e+00   -3.075656481e-06  -3.461579854e-06  9.5e-10  0.20
# 14  6.3e-08  5.8e-10  2.6e-13  1.36e+00   -1.075958436e-06  -1.273953033e-06  6.4e-10  0.20
# 15  1.5e-08  2.6e-09  2.9e-14  8.81e-01   -4.336243757e-07  -4.957680170e-07  1.4e-10  0.20
# 16  5.9e-09  1.2e-08  1.5e-15  1.00e+00   6.059170735e-09   -6.112351522e-10  2.2e-11  0.25
# Optimizer terminated. Time: 0.28
#
# SDP solving time: 0.2800749 seconds.
# optimum = 6.059170735175387e-9
# (6.059170735175387e-9, nothing, TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], 3.9013984560897357a₁₋₁⁴ - 6.8275060551687385a₁₋₁³a₂₋₁ + 7.149253186027157a₁₋₁³a₁₋₂ - 15.605593824358943a₁₋₁³a₂₋₂ - 15.836285113303198a₁₋₁³b₂₋₁ - 17.742161423756077a₁₋₁³b₁₋₂ + 27.631079865289387a₁₋₁²a₂₋₁² - 31.909351963306776a₁₋₁²a₂₋₁a₁₋₂ + 20.804265296364633a₁₋₁²a₂₋₁a₂₋₂ + 15.836285113303198a₁₋₁²a₂₋₁b₁₋₁ + 10.560669369472265a₁₋₁²a₂₋₁b₁₋₂ - 49.41473165036247a₁₋₁²a₂₋₁b₂₋₂ + 35.25510180274852a₁₋₁²a₁₋₂² - 21.769506688939884a₁₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₁₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₂₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₁₋₂ + 15.8362851133032a₁₋₁²a₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²a₂₋₂² + 49.41473165036247a₁₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₁₋₁²a₂₋₂b₁₋₂ + 7.802796912179471a₁₋₁²b₁₋₁² - 6.8275060551687385a₁₋₁²b₁₋₁b₂₋₁ + 7.149253186027157a₁₋₁²b₁₋₁b₁₋₂ - 15.605593824358943a₁₋₁²b₁₋₁b₂₋₂ + 27.631079865289387a₁₋₁²b₂₋₁² + 53.31132004974846a₁₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₁₋₁²b₂₋₁b₂₋₂ + 45.956085845969355a₁₋₁²b₁₋₂² + 6.8275060551687385a₁₋₁²b₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²b₂₋₂² - 6.8275060551687385a₁₋₁a₂₋₁³ + 7.149253186027158a₁₋₁a₂₋₁²a₁₋₂ - 58.21592983088656a₁₋₁a₂₋₁²a₂₋₂ - 15.836285113303198a₁₋₁a₂₋₁²b₂₋₁ - 17.742161423756077a₁₋₁a₂₋₁²b₁₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₁₋₂² + 69.2575282392556a₁₋₁a₂₋₁a₁₋₂a₂₋₂ - 10.560669369472265a₁₋₁a₂₋₁a₁₋₂b₂₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₂₋₂² - 10.560669369472265a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + 70.9686456950243a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₁₋₁² - 85.22067201305524a₁₋₁a₂₋₁b₁₋₁b₁₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₂₋₁² - 21.126012427223053a₁₋₁a₂₋₁b₁₋₂² + 90.65949632569733a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + 7.471000316885574a₁₋₁a₂₋₁b₂₋₂² + 22.0912538197983a₁₋₁a₁₋₂³ - 72.99525781783133a₁₋₁a₁₋₂²a₂₋₂ + 10.560669369472265a₁₋₁a₁₋₂²b₁₋₁ - 51.32060796081537a₁₋₁a₁₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₁₋₂²b₁₋₂ + 22.0912538197983a₁₋₁a₁₋₂a₂₋₂² - 70.9686456950243a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + 10.560669369472265a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + 7.149253186027157a₁₋₁a₁₋₂b₁₋₁² - 85.22067201305524a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 21.40196808644169a₁₋₁a₁₋₂b₁₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + 7.149253186027158a₁₋₁a₁₋₂b₂₋₁² + 69.2575282392556a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + 22.0912538197983a₁₋₁a₁₋₂b₁₋₂² + 22.0912538197983a₁₋₁a₁₋₂b₂₋₂² - 15.605593824358943a₁₋₁a₂₋₂³ - 51.320607960815366a₁₋₁a₂₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₂₋₂²b₁₋₂ - 15.605593824358943a₁₋₁a₂₋₂b₁₋₁² - 28.59701274410863a₁₋₁a₂₋₂b₁₋₁b₁₋₂ - 58.21592983088656a₁₋₁a₂₋₂b₂₋₁² - 90.65949632569735a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₂₋₂b₂₋₁b₂₋₂ - 72.99525781783133a₁₋₁a₂₋₂b₁₋₂² - 15.605593824358943a₁₋₁a₂₋₂b₂₋₂² - 15.836285113303198a₁₋₁b₁₋₁²b₂₋₁ - 17.742161423756077a₁₋₁b₁₋₁²b₁₋₂ - 10.560669369472265a₁₋₁b₁₋₁b₁₋₂² + 70.9686456950243a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 15.836285113303198a₁₋₁b₂₋₁³ - 17.742161423756077a₁₋₁b₂₋₁²b₁₋₂ - 51.32060796081537a₁₋₁b₂₋₁b₁₋₂² - 10.560669369472265a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + 19.648037734208966a₁₋₁b₂₋₁b₂₋₂² - 57.03823689217399a₁₋₁b₁₋₂³ - 57.03823689217399a₁₋₁b₁₋₂b₂₋₂² + 23.729681409199653a₂₋₁⁴ + 10.700984043220846a₂₋₁³a₁₋₂ + 20.804265296364633a₂₋₁³a₂₋₂ + 15.836285113303198a₂₋₁³b₁₋₁ + 10.560669369472265a₂₋₁³b₁₋₂ - 49.41473165036247a₂₋₁³b₂₋₂ - 22.155715370297a₂₋₁²a₁₋₂² - 21.769506688939884a₂₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₂₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₂₋₁²a₁₋₂b₂₋₁ - 55.13236058172113a₂₋₁²a₁₋₂b₂₋₂ + 35.25510180274852a₂₋₁²a₂₋₂² + 49.41473165036247a₂₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₂₋₁²a₂₋₂b₁₋₂ - 10.560669369472265a₂₋₁²a₂₋₂b₂₋₂ + 27.631079865289387a₂₋₁²b₁₋₁² - 6.8275060551687385a₂₋₁²b₁₋₁b₂₋₁ + 7.149253186027158a₂₋₁²b₁₋₁b₁₋₂ - 58.21592983088656a₂₋₁²b₁₋₁b₂₋₂ + 47.459362818399306a₂₋₁²b₂₋₁² + 10.700984043220846a₂₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₂₋₁²b₂₋₁b₂₋₂ - 22.155715370297a₂₋₁²b₁₋₂² - 21.769506688939884a₂₋₁²b₁₋₂b₂₋₂ + 45.956085845969355a₂₋₁²b₂₋₂² + 10.700984043220846a₂₋₁a₁₋₂³ + 7.149253186027157a₂₋₁a₁₋₂²a₂₋₂ + 51.32060796081537a₂₋₁a₁₋₂²b₁₋₁ + 10.560669369472265a₂₋₁a₁₋₂²b₁₋₂ - 17.74216142375608a₂₋₁a₁₋₂²b₂₋₂ - 46.68867995025157a₂₋₁a₁₋₂a₂₋₂² + 10.560669369472265a₂₋₁a₁₋₂a₂₋₂b₁₋₁ + 53.31132004974846a₂₋₁a ...

# %%
obj_ser
# Out:
# (3.9013984560897357 + 0.0im)a₁₋₁⁴ + (-6.8275060551687385 + 0.0im)a₁₋₁³a₂₋₁ + (7.149253186027157 + 0.0im)a₁₋₁³a₁₋₂ + (-15.605593824358943 + 0.0im)a₁₋₁³a₂₋₂ + (-15.836285113303198 + 0.0im)a₁₋₁³b₂₋₁ + (-17.742161423756077 + 0.0im)a₁₋₁³b₁₋₂ + (27.631079865289387 + 0.0im)a₁₋₁²a₂₋₁² + (-31.909351963306776 + 0.0im)a₁₋₁²a₂₋₁a₁₋₂ + (20.804265296364633 + 0.0im)a₁₋₁²a₂₋₁a₂₋₂ + (15.836285113303198 + 0.0im)a₁₋₁²a₂₋₁b₁₋₁ + (10.560669369472265 + 0.0im)a₁₋₁²a₂₋₁b₁₋₂ + (-49.41473165036247 + 0.0im)a₁₋₁²a₂₋₁b₂₋₂ + (35.25510180274852 + 0.0im)a₁₋₁²a₁₋₂² + (-21.769506688939884 + 0.0im)a₁₋₁²a₁₋₂a₂₋₂ + (17.742161423756077 + 0.0im)a₁₋₁²a₁₋₂b₁₋₁ + (-10.560669369472265 + 0.0im)a₁₋₁²a₁₋₂b₂₋₁ + (-10.560669369472265 + 0.0im)a₁₋₁²a₁₋₂b₁₋₂ + (15.8362851133032 + 7.28583859910259e-17im)a₁₋₁²a₁₋₂b₂₋₂ + (23.40839073653841 + 0.0im)a₁₋₁²a₂₋₂² + (49.41473165036247 + 8.088148206741863e-17im)a₁₋₁²a₂₋₂b₂₋₁ + (55.13236058172113 - 7.28583859910259e-17im)a₁₋₁²a₂₋₂b₁₋₂ + (7.802796912179471 + 0.0im)a₁₋₁²b₁₋₁² + (-6.8275060551687385 + 0.0im)a₁₋₁²b₁₋₁b₂₋₁ + (7.149253186027157 + 0.0im)a₁₋₁²b₁₋₁b₁₋₂ + (-15.605593824358943 + 0.0im)a₁₋₁²b₁₋₁b₂₋₂ + (27.631079865289387 + 0.0im)a₁₋₁²b₂₋₁² + (53.31132004974846 + 0.0im)a₁₋₁²b₂₋₁b₁₋₂ + (20.804265296364633 + 0.0im)a₁₋₁²b₂₋₁b₂₋₂ + (45.956085845969355 + 0.0im)a₁₋₁²b₁₋₂² + (6.8275060551687385 + 8.326672684688674e-17im)a₁₋₁²b₁₋₂b₂₋₂ + (23.40839073653841 + 0.0im)a₁₋₁²b₂₋₂² + (-6.8275060551687385 + 0.0im)a₁₋₁a₂₋₁³ + (7.149253186027158 + 0.0im)a₁₋₁a₂₋₁²a₁₋₂ + (-58.21592983088656 + 0.0im)a₁₋₁a₂₋₁²a₂₋₂ + (-15.836285113303198 + 0.0im)a₁₋₁a₂₋₁²b₂₋₁ + (-17.742161423756077 - 1.0842021724855044e-19im)a₁₋₁a₂₋₁²b₁₋₂ + (0.0 + 2.7755575615628914e-17im)a₁₋₁a₂₋₁²b₂₋₂ + (-21.126012427223053 + 0.0im)a₁₋₁a₂₋₁a₁₋₂² + (69.2575282392556 + 0.0im)a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + (-10.560669369472265 + 0.0im)a₁₋₁a₂₋₁a₁₋₂b₂₋₂ + (-21.126012427223053 + 0.0im)a₁₋₁a₂₋₁a₂₋₂² + (-10.560669369472265 + 0.0im)a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + (70.9686456950243 + 0.0im)a₁₋₁a₂₋₁a₂₋₂b₂₋₂ + (-6.8275060551687385 + 0.0im)a₁₋₁a₂₋₁b₁₋₁² + (-85.22067201305524 + 0.0im)a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + (-6.8275060551687385 + 0.0im)a₁₋₁a₂₋₁b₂₋₁² + (-21.126012427223053 + 0.0im)a₁₋₁a₂₋₁b₁₋₂² + (90.65949632569733 + 0.0im)a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + (7.471000316885574 - 1.8041124150158794e-16im)a₁₋₁a₂₋₁b₂₋₂² + (22.0912538197983 + 0.0im)a₁₋₁a₁₋₂³ + (-72.99525781783133 + 0.0im)a₁₋₁a₁₋₂²a₂₋₂ + (10.560669369472265 + 0.0im)a₁₋₁a₁₋₂²b₁₋₁ + (-51.32060796081537 - 6.938893903907228e-18im)a₁₋₁a₁₋₂²b₂₋₁ + (-57.03823689217399 + 0.0im)a₁₋₁a₁₋₂²b₁₋₂ + (0.0 + 2.7755575615628914e-17im)a₁₋₁a₁₋₂²b₂₋₂ + (22.0912538197983 - 1.3877787807814457e-17im)a₁₋₁a₁₋₂a₂₋₂² + (-70.9686456950243 + 0.0im)a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + (10.560669369472265 + 0.0im)a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + (7.149253186027157 + 0.0im)a₁₋₁a₁₋₂b₁₋₁² + (-85.22067201305524 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₁ + (-21.40196808644169 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + (-28.59701274410863 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + (7.149253186027158 + 0.0im)a₁₋₁a₁₋₂b₂₋₁² + (69.2575282392556 + 0.0im)a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + (22.0912538197983 + 0.0im)a₁₋₁a₁₋₂b₁₋₂² + (22.0912538197983 - 1.3877787807814457e-17im)a₁₋₁a₁₋₂b₂₋₂² + (-15.605593824358943 + 0.0im)a₁₋₁a₂₋₂³ + (-51.320607960815366 - 8.673617379884035e-18im)a₁₋₁a₂₋₂²b₂₋₁ + (-57.03823689217399 + 6.071532165918825e-18im)a₁₋₁a₂₋₂²b₁₋₂ + (-15.605593824358943 + 0.0im)a₁₋₁a₂₋₂b₁₋₁² + (-28.59701274410863 + 0.0im)a₁₋₁a₂₋₂b₁₋₁b₁₋₂ + (-58.21592983088656 + 0.0im)a₁₋₁a₂₋₂b₂₋₁² + (-90.65949632569735 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₁₋₂ + (-28.59701274410863 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₂₋₂ + (-72.99525781783133 + 0.0im)a₁₋₁a₂₋₂b₁₋₂² + (-15.605593824358943 + 0.0im)a₁₋₁a₂₋₂b₂₋₂² + (-15.836285113303198 + 0.0im)a₁₋₁b₁₋₁²b₂₋₁ + (-17.742161423756077 + 0.0im)a₁₋₁b₁₋₁²b₁₋₂ + (-10.560669369472265 + 0.0im)a₁₋₁b₁₋₁b₁₋₂² + (70.9686456950243 + 0.0im)a₁₋₁b₁₋₁b₁₋₂b₂₋₂ + (-15.836285113303198 + 0.0im)a₁₋₁b₂₋₁³ + (-17.742161423756077 - 1.0842021724855044e-19im)a₁₋₁b₂₋₁²b₁₋₂ + (0.0 + 2.7755575615628914e-17im)a₁₋₁b₂₋₁²b₂₋₂ + (-51.32060796081537 - 1.8973538018496328e-18im)a₁₋₁b₂₋₁b₁₋₂² + (-10.560669369472265 + 0.0im)a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + (19.648037734208966 + 6.776 ...

# %%
opt,sol,data = tssos_higher!(data)
# Out:
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [41, 8]
# [1, 1]
# ------------------------------------------------------
# Obtained the block structure. The maximal size of blocks is 41.
# Assembling the SDP...
# There are 525 affine constraints.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 525
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 525
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 525
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2                 conic                  : 2
# Optimizer  - Semi-definite variables: 2                 scalarized             : 897
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 1.38e+05          after factor           : 1.38e+05
# Factor     - dense dim.             : 0                 flops                  : 5.04e+07
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.1e+02  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   4.6e+01  4.0e-01  6.3e-01  -9.92e-01  -1.724139154e+00  -3.158769471e+00  4.0e-01  0.06
# 2   1.0e+01  9.0e-02  2.7e-01  -9.62e-01  -2.909845337e+01  -3.754282079e+01  9.0e-02  0.06
# 3   2.3e+00  2.0e-02  6.3e-02  -5.91e-01  -4.381421815e+01  -5.361025023e+01  2.0e-02  0.08
# 4   5.4e-01  4.7e-03  7.1e-03  6.07e-01   -1.082030576e+01  -1.293588013e+01  4.7e-03  0.09
# 5   8.4e-02  7.3e-04  4.0e-04  9.43e-01   -1.936514544e+00  -2.225717066e+00  7.3e-04  0.11
# 6   1.3e-02  1.1e-04  2.3e-05  9.84e-01   -3.357930908e-01  -3.760983121e-01  1.1e-04  0.13
# 7   2.4e-03  2.1e-05  1.9e-06  1.00e+00   -6.857043340e-02  -7.644375229e-02  2.1e-05  0.14
# 8   5.3e-04  4.6e-06  2.0e-07  9.87e-01   -1.426025629e-02  -1.599712726e-02  4.6e-06  0.16
# 9   9.7e-05  8.5e-07  1.5e-08  9.35e-01   -2.764867693e-03  -3.063976199e-03  8.5e-07  0.16
# 10  2.1e-05  1.8e-07  1.6e-09  1.00e+00   -6.343110038e-04  -7.016467271e-04  1.8e-07  0.17
# 11  4.6e-06  4.0e-08  1.6e-10  1.05e+00   -1.489326910e-04  -1.637949323e-04  4.0e-08  0.17
# 12  6.3e-07  5.5e-09  8.3e-12  1.07e+00   -2.224267381e-05  -2.438787933e-05  6.0e-09  0.20
# 13  3.1e-07  2.7e-09  3.1e-12  1.06e+00   -1.699007497e-05  -1.820543695e-05  3.1e-09  0.23
# 14  5.7e-08  5.1e-10  1.1e-13  1.15e+00   -1.872289405e-06  -1.914460307e-06  5.1e-10  0.25
# 15  1.3e-08  7.0e-10  1.3e-14  9.96e-01   -5.239716130e-07  -5.439586821e-07  9.2e-11  0.25
# 16  8.1e-09  1.1e-09  8.4e-16  1.00e+00   -7.077608496e-08  -7.439356498e-08  1.4e-11  0.27
# Optimizer terminated. Time: 0.27
#
# SDP solving time: 0.265243 seconds.
# optimum = -7.077608496076209e-8
# (-7.077608496076209e-8, nothing, TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], 3.9013984560897357a₁₋₁⁴ - 6.8275060551687385a₁₋₁³a₂₋₁ + 7.149253186027157a₁₋₁³a₁₋₂ - 15.605593824358943a₁₋₁³a₂₋₂ - 15.836285113303198a₁₋₁³b₂₋₁ - 17.742161423756077a₁₋₁³b₁₋₂ + 27.631079865289387a₁₋₁²a₂₋₁² - 31.909351963306776a₁₋₁²a₂₋₁a₁₋₂ + 20.804265296364633a₁₋₁²a₂₋₁a₂₋₂ + 15.836285113303198a₁₋₁²a₂₋₁b₁₋₁ + 10.560669369472265a₁₋₁²a₂₋₁b₁₋₂ - 49.41473165036247a₁₋₁²a₂₋₁b₂₋₂ + 35.25510180274852a₁₋₁²a₁₋₂² - 21.769506688939884a₁₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₁₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₂₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₁₋₂ + 15.8362851133032a₁₋₁²a₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²a₂₋₂² + 49.41473165036247a₁₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₁₋₁²a₂₋₂b₁₋₂ + 7.802796912179471a₁₋₁²b₁₋₁² - 6.8275060551687385a₁₋₁²b₁₋₁b₂₋₁ + 7.149253186027157a₁₋₁²b₁₋₁b₁₋₂ - 15.605593824358943a₁₋₁²b₁₋₁b₂₋₂ + 27.631079865289387a₁₋₁²b₂₋₁² + 53.31132004974846a₁₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₁₋₁²b₂₋₁b₂₋₂ + 45.956085845969355a₁₋₁²b₁₋₂² + 6.8275060551687385a₁₋₁²b₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²b₂₋₂² - 6.8275060551687385a₁₋₁a₂₋₁³ + 7.149253186027158a₁₋₁a₂₋₁²a₁₋₂ - 58.21592983088656a₁₋₁a₂₋₁²a₂₋₂ - 15.836285113303198a₁₋₁a₂₋₁²b₂₋₁ - 17.742161423756077a₁₋₁a₂₋₁²b₁₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₁₋₂² + 69.2575282392556a₁₋₁a₂₋₁a₁₋₂a₂₋₂ - 10.560669369472265a₁₋₁a₂₋₁a₁₋₂b₂₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₂₋₂² - 10.560669369472265a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + 70.9686456950243a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₁₋₁² - 85.22067201305524a₁₋₁a₂₋₁b₁₋₁b₁₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₂₋₁² - 21.126012427223053a₁₋₁a₂₋₁b₁₋₂² + 90.65949632569733a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + 7.471000316885574a₁₋₁a₂₋₁b₂₋₂² + 22.0912538197983a₁₋₁a₁₋₂³ - 72.99525781783133a₁₋₁a₁₋₂²a₂₋₂ + 10.560669369472265a₁₋₁a₁₋₂²b₁₋₁ - 51.32060796081537a₁₋₁a₁₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₁₋₂²b₁₋₂ + 22.0912538197983a₁₋₁a₁₋₂a₂₋₂² - 70.9686456950243a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + 10.560669369472265a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + 7.149253186027157a₁₋₁a₁₋₂b₁₋₁² - 85.22067201305524a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 21.40196808644169a₁₋₁a₁₋₂b₁₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + 7.149253186027158a₁₋₁a₁₋₂b₂₋₁² + 69.2575282392556a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + 22.0912538197983a₁₋₁a₁₋₂b₁₋₂² + 22.0912538197983a₁₋₁a₁₋₂b₂₋₂² - 15.605593824358943a₁₋₁a₂₋₂³ - 51.320607960815366a₁₋₁a₂₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₂₋₂²b₁₋₂ - 15.605593824358943a₁₋₁a₂₋₂b₁₋₁² - 28.59701274410863a₁₋₁a₂₋₂b₁₋₁b₁₋₂ - 58.21592983088656a₁₋₁a₂₋₂b₂₋₁² - 90.65949632569735a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₂₋₂b₂₋₁b₂₋₂ - 72.99525781783133a₁₋₁a₂₋₂b₁₋₂² - 15.605593824358943a₁₋₁a₂₋₂b₂₋₂² - 15.836285113303198a₁₋₁b₁₋₁²b₂₋₁ - 17.742161423756077a₁₋₁b₁₋₁²b₁₋₂ - 10.560669369472265a₁₋₁b₁₋₁b₁₋₂² + 70.9686456950243a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 15.836285113303198a₁₋₁b₂₋₁³ - 17.742161423756077a₁₋₁b₂₋₁²b₁₋₂ - 51.32060796081537a₁₋₁b₂₋₁b₁₋₂² - 10.560669369472265a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + 19.648037734208966a₁₋₁b₂₋₁b₂₋₂² - 57.03823689217399a₁₋₁b₁₋₂³ - 57.03823689217399a₁₋₁b₁₋₂b₂₋₂² + 23.729681409199653a₂₋₁⁴ + 10.700984043220846a₂₋₁³a₁₋₂ + 20.804265296364633a₂₋₁³a₂₋₂ + 15.836285113303198a₂₋₁³b₁₋₁ + 10.560669369472265a₂₋₁³b₁₋₂ - 49.41473165036247a₂₋₁³b₂₋₂ - 22.155715370297a₂₋₁²a₁₋₂² - 21.769506688939884a₂₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₂₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₂₋₁²a₁₋₂b₂₋₁ - 55.13236058172113a₂₋₁²a₁₋₂b₂₋₂ + 35.25510180274852a₂₋₁²a₂₋₂² + 49.41473165036247a₂₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₂₋₁²a₂₋₂b₁₋₂ - 10.560669369472265a₂₋₁²a₂₋₂b₂₋₂ + 27.631079865289387a₂₋₁²b₁₋₁² - 6.8275060551687385a₂₋₁²b₁₋₁b₂₋₁ + 7.149253186027158a₂₋₁²b₁₋₁b₁₋₂ - 58.21592983088656a₂₋₁²b₁₋₁b₂₋₂ + 47.459362818399306a₂₋₁²b₂₋₁² + 10.700984043220846a₂₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₂₋₁²b₂₋₁b₂₋₂ - 22.155715370297a₂₋₁²b₁₋₂² - 21.769506688939884a₂₋₁²b₁₋₂b₂₋₂ + 45.956085845969355a₂₋₁²b₂₋₂² + 10.700984043220846a₂₋₁a₁₋₂³ + 7.149253186027157a₂₋₁a₁₋₂²a₂₋₂ + 51.32060796081537a₂₋₁a₁₋₂²b₁₋₁ + 10.560669369472265a₂₋₁a₁₋₂²b₁₋₂ - 17.74216142375608a₂₋₁a₁₋₂²b₂₋₂ - 46.68867995025157a₂₋₁a₁₋₂a₂₋₂² + 10.560669369472265a₂₋₁a₁₋₂a₂₋₂b₁₋₁ + 53.31132004974846a₂₋₁ ...

# %%
opt,sol,data = tssos_higher!(data)
# Out:
# Starting to compute the block structure...
# No higher TSSOS hierarchy!
# (nothing, nothing, TSSOS.upop_data(12, 0, PolyVar{true}[x₁, x₂, x₃, x₄, a₁₋₁, a₂₋₁, a₁₋₂, a₂₋₂, b₁₋₁, b₂₋₁, b₁₋₂, b₂₋₂], 3.9013984560897357a₁₋₁⁴ - 6.8275060551687385a₁₋₁³a₂₋₁ + 7.149253186027157a₁₋₁³a₁₋₂ - 15.605593824358943a₁₋₁³a₂₋₂ - 15.836285113303198a₁₋₁³b₂₋₁ - 17.742161423756077a₁₋₁³b₁₋₂ + 27.631079865289387a₁₋₁²a₂₋₁² - 31.909351963306776a₁₋₁²a₂₋₁a₁₋₂ + 20.804265296364633a₁₋₁²a₂₋₁a₂₋₂ + 15.836285113303198a₁₋₁²a₂₋₁b₁₋₁ + 10.560669369472265a₁₋₁²a₂₋₁b₁₋₂ - 49.41473165036247a₁₋₁²a₂₋₁b₂₋₂ + 35.25510180274852a₁₋₁²a₁₋₂² - 21.769506688939884a₁₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₁₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₂₋₁ - 10.560669369472265a₁₋₁²a₁₋₂b₁₋₂ + 15.8362851133032a₁₋₁²a₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²a₂₋₂² + 49.41473165036247a₁₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₁₋₁²a₂₋₂b₁₋₂ + 7.802796912179471a₁₋₁²b₁₋₁² - 6.8275060551687385a₁₋₁²b₁₋₁b₂₋₁ + 7.149253186027157a₁₋₁²b₁₋₁b₁₋₂ - 15.605593824358943a₁₋₁²b₁₋₁b₂₋₂ + 27.631079865289387a₁₋₁²b₂₋₁² + 53.31132004974846a₁₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₁₋₁²b₂₋₁b₂₋₂ + 45.956085845969355a₁₋₁²b₁₋₂² + 6.8275060551687385a₁₋₁²b₁₋₂b₂₋₂ + 23.40839073653841a₁₋₁²b₂₋₂² - 6.8275060551687385a₁₋₁a₂₋₁³ + 7.149253186027158a₁₋₁a₂₋₁²a₁₋₂ - 58.21592983088656a₁₋₁a₂₋₁²a₂₋₂ - 15.836285113303198a₁₋₁a₂₋₁²b₂₋₁ - 17.742161423756077a₁₋₁a₂₋₁²b₁₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₁₋₂² + 69.2575282392556a₁₋₁a₂₋₁a₁₋₂a₂₋₂ - 10.560669369472265a₁₋₁a₂₋₁a₁₋₂b₂₋₂ - 21.126012427223053a₁₋₁a₂₋₁a₂₋₂² - 10.560669369472265a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + 70.9686456950243a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₁₋₁² - 85.22067201305524a₁₋₁a₂₋₁b₁₋₁b₁₋₂ - 6.8275060551687385a₁₋₁a₂₋₁b₂₋₁² - 21.126012427223053a₁₋₁a₂₋₁b₁₋₂² + 90.65949632569733a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + 7.471000316885574a₁₋₁a₂₋₁b₂₋₂² + 22.0912538197983a₁₋₁a₁₋₂³ - 72.99525781783133a₁₋₁a₁₋₂²a₂₋₂ + 10.560669369472265a₁₋₁a₁₋₂²b₁₋₁ - 51.32060796081537a₁₋₁a₁₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₁₋₂²b₁₋₂ + 22.0912538197983a₁₋₁a₁₋₂a₂₋₂² - 70.9686456950243a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + 10.560669369472265a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + 7.149253186027157a₁₋₁a₁₋₂b₁₋₁² - 85.22067201305524a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 21.40196808644169a₁₋₁a₁₋₂b₁₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + 7.149253186027158a₁₋₁a₁₋₂b₂₋₁² + 69.2575282392556a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + 22.0912538197983a₁₋₁a₁₋₂b₁₋₂² + 22.0912538197983a₁₋₁a₁₋₂b₂₋₂² - 15.605593824358943a₁₋₁a₂₋₂³ - 51.320607960815366a₁₋₁a₂₋₂²b₂₋₁ - 57.03823689217399a₁₋₁a₂₋₂²b₁₋₂ - 15.605593824358943a₁₋₁a₂₋₂b₁₋₁² - 28.59701274410863a₁₋₁a₂₋₂b₁₋₁b₁₋₂ - 58.21592983088656a₁₋₁a₂₋₂b₂₋₁² - 90.65949632569735a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 28.59701274410863a₁₋₁a₂₋₂b₂₋₁b₂₋₂ - 72.99525781783133a₁₋₁a₂₋₂b₁₋₂² - 15.605593824358943a₁₋₁a₂₋₂b₂₋₂² - 15.836285113303198a₁₋₁b₁₋₁²b₂₋₁ - 17.742161423756077a₁₋₁b₁₋₁²b₁₋₂ - 10.560669369472265a₁₋₁b₁₋₁b₁₋₂² + 70.9686456950243a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 15.836285113303198a₁₋₁b₂₋₁³ - 17.742161423756077a₁₋₁b₂₋₁²b₁₋₂ - 51.32060796081537a₁₋₁b₂₋₁b₁₋₂² - 10.560669369472265a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + 19.648037734208966a₁₋₁b₂₋₁b₂₋₂² - 57.03823689217399a₁₋₁b₁₋₂³ - 57.03823689217399a₁₋₁b₁₋₂b₂₋₂² + 23.729681409199653a₂₋₁⁴ + 10.700984043220846a₂₋₁³a₁₋₂ + 20.804265296364633a₂₋₁³a₂₋₂ + 15.836285113303198a₂₋₁³b₁₋₁ + 10.560669369472265a₂₋₁³b₁₋₂ - 49.41473165036247a₂₋₁³b₂₋₂ - 22.155715370297a₂₋₁²a₁₋₂² - 21.769506688939884a₂₋₁²a₁₋₂a₂₋₂ + 17.742161423756077a₂₋₁²a₁₋₂b₁₋₁ - 10.560669369472265a₂₋₁²a₁₋₂b₂₋₁ - 55.13236058172113a₂₋₁²a₁₋₂b₂₋₂ + 35.25510180274852a₂₋₁²a₂₋₂² + 49.41473165036247a₂₋₁²a₂₋₂b₂₋₁ + 55.13236058172113a₂₋₁²a₂₋₂b₁₋₂ - 10.560669369472265a₂₋₁²a₂₋₂b₂₋₂ + 27.631079865289387a₂₋₁²b₁₋₁² - 6.8275060551687385a₂₋₁²b₁₋₁b₂₋₁ + 7.149253186027158a₂₋₁²b₁₋₁b₁₋₂ - 58.21592983088656a₂₋₁²b₁₋₁b₂₋₂ + 47.459362818399306a₂₋₁²b₂₋₁² + 10.700984043220846a₂₋₁²b₂₋₁b₁₋₂ + 20.804265296364633a₂₋₁²b₂₋₁b₂₋₂ - 22.155715370297a₂₋₁²b₁₋₂² - 21.769506688939884a₂₋₁²b₁₋₂b₂₋₂ + 45.956085845969355a₂₋₁²b₂₋₂² + 10.700984043220846a₂₋₁a₁₋₂³ + 7.149253186027157a₂₋₁a₁₋₂²a₂₋₂ + 51.32060796081537a₂₋₁a₁₋₂²b₁₋₁ + 10.560669369472265a₂₋₁a₁₋₂²b₁₋₂ - 17.74216142375608a₂₋₁a₁₋₂²b₂₋₂ - 46.68867995025157a₂₋₁a₁₋₂a₂₋₂² + 10.560669369472265a₂₋₁a₁₋₂a₂₋₂b₁₋₁ + 53.31132004974846a₂₋₁a₁₋₂b₁₋₁² - 90 ...

# %%
fname="lindblad_pop_sid_fidelity_vs_noise_2021-11-10 13_55_21.743372.hdf5"
file = h5open(fname, "r")
# Out:
# 🗂️ HDF5.File: (read-only) lindblad_pop_sid_fidelity_vs_noise_2021-11-10 13_55_21.743372.hdf5
# ├─ 📂 0.0
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.01
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.02
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.04
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.05
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.1
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.2
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# ├─ 📂 0.4
# │  ├─ 🔢 min_fidelities
# │  └─ 🔢 seed
# └─ 📂 0.5
#    ├─ 🔢 min_fidelities
#    └─ 🔢 seed

# %%
dset = file["0.01"]["min_fidelities"]
# Out:
# 🔢 HDF5.Dataset: /0.01/min_fidelities (file: lindblad_pop_sid_fidelity_vs_noise_2021-11-10 13_55_21.743372.hdf5 xfer_mode: 0)

# %%
fidelities = read(dset)
length(fidelities)
# Out:
# 1400

# %%
seeds_data = file["0.01"]["seed"]
seeds = read(seeds_data)
length(seeds)
# Out:
# 1400

# %%
string(seeds[1])
# Out:
# "826708973"

# %%
fname="time_series_lindblad_rnd_rho_2022-04-27_03-35-20.hdf5"
file = h5open(fname, "r")
# Out:
# 🗂️ HDF5.File: (read-only) time_series_lindblad_rnd_rho_2022-04-27_03-35-20.hdf5
# ├─ 📂 0.0
# │  ├─ 📂 1000923797
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001008430
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001165252
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001170376
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001173185
# │  │  └─ 🔢 rho
# │  ├─ 📂 100139632
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001402855
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001668053
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001691713
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001715003
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001811023
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001940489
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002593692
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002725820
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002756796
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002765241
# │  │  └─ 🔢 rho
# │  ├─ 📂 100298145
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003240607
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003544090
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003624526
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003918493
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004019322
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004304524
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004425389
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004549875
# │  │  └─ 🔢 rho
# │  └─ (21575 more children)
# ├─ 📂 0.01
# │  ├─ 📂 1000923797
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001008430
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001165252
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001170376
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001173185
# │  │  └─ 🔢 rho
# │  ├─ 📂 100139632
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001402855
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001668053
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001691713
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001715003
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001811023
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001940489
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002593692
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002725820
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002756796
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002765241
# │  │  └─ 🔢 rho
# │  ├─ 📂 100298145
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003240607
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003544090
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003624526
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003918493
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004019322
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004304524
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004425389
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004549875
# │  │  └─ 🔢 rho
# │  └─ (21575 more children)
# ├─ 📂 0.02
# │  ├─ 📂 1000923797
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001008430
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001165252
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001170376
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001173185
# │  │  └─ 🔢 rho
# │  ├─ 📂 100139632
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001402855
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001668053
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001691713
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001715003
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001811023
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001940489
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002593692
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002725820
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002756796
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002765241
# │  │  └─ 🔢 rho
# │  ├─ 📂 100298145
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003240607
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003544090
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003624526
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003918493
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004019322
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004304524
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004425389
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004549875
# │  │  └─ 🔢 rho
# │  └─ (21575 more children)
# ├─ 📂 0.04
# │  ├─ 📂 1000923797
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001008430
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001165252
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001170376
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001173185
# │  │  └─ 🔢 rho
# │  ├─ 📂 100139632
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001402855
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001668053
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001691713
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001715003
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001811023
# │  │  └─ 🔢 rho
# │  ├─ 📂 1001940489
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002593692
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002725820
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002756796
# │  │  └─ 🔢 rho
# │  ├─ 📂 1002765241
# │  │  └─ 🔢 rho
# │  ├─ 📂 100298145
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003240607
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003544090
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003624526
# │  │  └─ 🔢 rho
# │  ├─ 📂 1003918493
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004019322
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004304524
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004425389
# │  │  └─ 🔢 rho
# │  ├─ 📂 1004549875
# │  │  └─ 🔢 rho
# │  └─ (21575 more children)
# └─ 📂 0.05
#    ├─ 📂 1000923797
#    │  └─ 🔢 rho
#    ├─ 📂 1001008430
#    │  └─ 🔢 rho
#    ├─ 📂 1001165252
#    │  └─ 🔢 rho
#    ├─ 📂 1001170376
#    │  └─ 🔢 rho
#    ├─ 📂 1001173185
#    │  └─ 🔢 rho
#    ├─ 📂 100139632
#    │  └─ 🔢 rho
#    ├─ 📂 1001402855
#    │  └─ 🔢 rho
#    ├─ 📂 1001691713
#    │  └─ 🔢 rho
#    ├─ 📂 1001715003
#    │  └─ 🔢 rho
#    ├─ 📂 1001811023
#    │  └─ 🔢 rho
#    ├─ 📂 1001940489
#    │  └─ 🔢 rho
#    ├─ 📂 1002593692
#    │  └─ 🔢 rho
#    ├─ 📂 1002725820
#    │  └─ 🔢 rho
#    ├─ 📂 1002756796
#    │  └─ 🔢 rho
#    ├─ 📂 1002765241
#    │  └─ 🔢 rho
#    ├─ 📂 100298145
#    │  └─ 🔢 rho
#    ├─ 📂 1003544090
#    │  └─ 🔢 rho
#    ├─ 📂 1003624526
#    │  └─ 🔢 rho
#    ├─ 📂 1003918493
#    │  └─ 🔢 rho
#    ├─ 📂 1004019322
#    │  └─ 🔢 rho
#    ├─ 📂 1004304524
#    │  └─ 🔢 rho
#    ├─ 📂 1004425389
#    │  └─ 🔢 rho
#    ├─ 📂 1004549875
#    │  └─ 🔢 rho
#    ├─ 📂 1004800926
#    │  └─ 🔢 rho
#    ├─ 📂 1005104285
#    │  └─ 🔢 rho
#    └─ (20007 more children)

# %%
dset = file["0.0"]["1005104285"]["rho"]
# Out:
# 🔢 HDF5.Dataset: /0.0/1005104285/rho (file: time_series_lindblad_rnd_rho_2022-04-27_03-35-20.hdf5 xfer_mode: 0)

# %%
fname="time_series_lindblad_rnd_rho_2022-04-27_03-35-20.hdf5"
file = h5open(fname, "r")

dset = file["0.0"]["1001668053"]["rho"]
ρ_series = read(dset)

obj_ser = frobenius_norm2(lindblad_rhs(ρ_series[:, :, 1]))

for i in 2:size(ρ_series,3)
    obj_ser += frobenius_norm2(lindblad_rhs(ρ_series[:, :, i]))
end

# %%
obj_ser
# Out:
# (3.099544650085157 + 0.0im)a₁₋₁⁴ + (18.136797996489786 + 0.0im)a₁₋₁³a₂₋₁ + (-16.847648446778244 + 0.0im)a₁₋₁³a₁₋₂ + (-12.398178600340628 + 0.0im)a₁₋₁³a₂₋₂ + (-4.788194797287195 + 0.0im)a₁₋₁³b₂₋₁ + (-4.5103682570808985 + 0.0im)a₁₋₁³b₁₋₂ + (34.94721035012539 + 0.0im)a₁₋₁²a₂₋₁² + (-64.24979330303027 + 0.0im)a₁₋₁²a₂₋₁a₁₋₂ + (-53.121244439757824 + 0.0im)a₁₋₁²a₂₋₁a₂₋₂ + (4.788194797287195 + 0.0im)a₁₋₁²a₂₋₁b₁₋₁ + (-5.914404175367562 + 0.0im)a₁₋₁²a₂₋₁b₁₋₂ + (-14.086757851655289 + 0.0im)a₁₋₁²a₂₋₁b₂₋₂ + (42.73509586631987 + 0.0im)a₁₋₁²a₁₋₂² + (49.2537957906232 + 6.938893903907228e-18im)a₁₋₁²a₁₋₂a₂₋₂ + (4.5103682570808985 + 0.0im)a₁₋₁²a₁₋₂b₁₋₁ + (5.914404175367562 + 0.0im)a₁₋₁²a₁₋₂b₂₋₁ + (5.914404175367562 + 0.0im)a₁₋₁²a₁₋₂b₁₋₂ + (4.788194797287195 - 6.938893903907228e-17im)a₁₋₁²a₁₋₂b₂₋₂ + (18.597267900510957 + 0.0im)a₁₋₁²a₂₋₂² + (14.086757851655289 - 1.3877787807814457e-17im)a₁₋₁²a₂₋₂b₂₋₁ + (13.253278231036406 + 6.938893903907228e-17im)a₁₋₁²a₂₋₂b₁₋₂ + (6.199089300170314 + 0.0im)a₁₋₁²b₁₋₁² + (18.136797996489786 + 0.0im)a₁₋₁²b₁₋₁b₂₋₁ + (-16.847648446778244 + 0.0im)a₁₋₁²b₁₋₁b₁₋₂ + (-12.398178600340628 + 0.0im)a₁₋₁²b₁₋₁b₂₋₂ + (34.94721035012539 + 0.0im)a₁₋₁²b₂₋₁² + (42.902124239113355 + 0.0im)a₁₋₁²b₂₋₁b₁₋₂ + (-53.121244439757824 + 0.0im)a₁₋₁²b₂₋₁b₂₋₂ + (32.061261334361404 + 0.0im)a₁₋₁²b₁₋₂² + (-18.136797996489786 + 6.938893903907228e-18im)a₁₋₁²b₁₋₂b₂₋₂ + (18.597267900510957 + 0.0im)a₁₋₁²b₂₋₂² + (18.136797996489786 + 0.0im)a₁₋₁a₂₋₁³ + (-16.847648446778244 + 0.0im)a₁₋₁a₂₋₁²a₁₋₂ + (-65.97413737141247 + 0.0im)a₁₋₁a₂₋₁²a₂₋₂ + (-4.788194797287195 + 0.0im)a₁₋₁a₂₋₁²b₂₋₁ + (-4.5103682570808985 + 0.0im)a₁₋₁a₂₋₁²b₁₋₂ + (0.0 + 5.551115123125783e-17im)a₁₋₁a₂₋₁²b₂₋₂ + (51.832094890046264 + 0.0im)a₁₋₁a₂₋₁a₁₋₂² + (97.93133137385134 + 0.0im)a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + (5.914404175367562 + 0.0im)a₁₋₁a₂₋₁a₁₋₂b₂₋₂ + (51.832094890046264 + 0.0im)a₁₋₁a₂₋₁a₂₋₂² + (5.914404175367562 + 0.0im)a₁₋₁a₂₋₁a₂₋₂b₁₋₂ + (18.041473028323594 + 0.0im)a₁₋₁a₂₋₁a₂₋₂b₂₋₂ + (18.136797996489786 + 0.0im)a₁₋₁a₂₋₁b₁₋₁² + (-107.1519175421436 + 0.0im)a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + (18.136797996489786 + 0.0im)a₁₋₁a₂₋₁b₂₋₁² + (51.832094890046264 + 0.0im)a₁₋₁a₂₋₁b₁₋₂² + (76.58366230993438 + 0.0im)a₁₋₁a₂₋₁b₁₋₂b₂₋₂ + (-15.558498897066707 + 8.326672684688674e-17im)a₁₋₁a₂₋₁b₂₋₂² + (-47.96464624091166 + 0.0im)a₁₋₁a₁₋₂³ + (-58.82221982926878 + 0.0im)a₁₋₁a₁₋₂²a₂₋₂ + (-5.914404175367562 + 0.0im)a₁₋₁a₁₋₂²b₁₋₁ + (-13.808931311448992 + 0.0im)a₁₋₁a₁₋₂²b₂₋₁ + (-12.975451690830107 + 0.0im)a₁₋₁a₁₋₂²b₁₋₂ + (0.0 + 1.3877787807814457e-16im)a₁₋₁a₁₋₂²b₂₋₂ + (-47.96464624091166 + 0.0im)a₁₋₁a₁₋₂a₂₋₂² + (-18.041473028323594 + 0.0im)a₁₋₁a₁₋₂a₂₋₂b₁₋₁ + (-5.914404175367562 + 0.0im)a₁₋₁a₁₋₂a₂₋₂b₂₋₁ + (-16.847648446778244 + 0.0im)a₁₋₁a₁₋₂b₁₋₁² + (-107.1519175421436 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₁ + (21.347669063916932 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + (67.39059378711298 + 0.0im)a₁₋₁a₁₋₂b₁₋₁b₂₋₂ + (-16.847648446778244 + 0.0im)a₁₋₁a₁₋₂b₂₋₁² + (97.93133137385134 + 0.0im)a₁₋₁a₁₋₂b₂₋₁b₂₋₂ + (-47.96464624091166 + 0.0im)a₁₋₁a₁₋₂b₁₋₂² + (-47.96464624091166 + 0.0im)a₁₋₁a₁₋₂b₂₋₂² + (-12.398178600340628 + 0.0im)a₁₋₁a₂₋₂³ + (-13.808931311448992 + 0.0im)a₁₋₁a₂₋₂²b₂₋₁ + (-12.975451690830107 + 0.0im)a₁₋₁a₂₋₂²b₁₋₂ + (-12.398178600340628 + 0.0im)a₁₋₁a₂₋₂b₁₋₁² + (67.39059378711298 + 0.0im)a₁₋₁a₂₋₂b₁₋₁b₁₋₂ + (-65.97413737141247 + 0.0im)a₁₋₁a₂₋₂b₂₋₁² + (-76.58366230993438 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₁₋₂ + (67.39059378711298 + 0.0im)a₁₋₁a₂₋₂b₂₋₁b₂₋₂ + (-58.82221982926878 + 0.0im)a₁₋₁a₂₋₂b₁₋₂² + (-12.398178600340628 + 0.0im)a₁₋₁a₂₋₂b₂₋₂² + (-4.788194797287195 + 0.0im)a₁₋₁b₁₋₁²b₂₋₁ + (-4.5103682570808985 + 0.0im)a₁₋₁b₁₋₁²b₁₋₂ + (5.914404175367562 + 0.0im)a₁₋₁b₁₋₁b₁₋₂² + (18.041473028323594 + 0.0im)a₁₋₁b₁₋₁b₁₋₂b₂₋₂ + (-4.788194797287195 + 0.0im)a₁₋₁b₂₋₁³ + (-4.5103682570808985 + 0.0im)a₁₋₁b₂₋₁²b₁₋₂ + (0.0 + 5.551115123125783e-17im)a₁₋₁b₂₋₁²b₂₋₂ + (-13.808931311448992 + 0.0im)a₁₋₁b₂₋₁b₁₋₂² + (5.914404175367562 + 0.0im)a₁₋₁b₂₋₁b₁₋₂b₂₋₂ + (4.232541716874606 - 2.498001805406602e-16im)a₁₋₁b₂₋₁b₂₋₂² + (-12.975451690830107 + 0.0im)a₁₋₁b₁₋₂³ + (0.0 + 1.3877787807814457e-16im)a₁₋₁b₁₋₂²b₂₋₂ + ( ...

# %%
#using TSSOS

opt,sol,data = tssos_first(obj_ser, variables(obj_ser))
# Out:
# ************************TSSOS************************
# TSSOS is launching...
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [41, 1]
# [1, 8]
# ------------------------------------------------------
# Obtained the block structure. The maximal size of blocks is 41.
# Assembling the SDP...
# There are 525 affine constraints.
# InexactError: Float64(49.2537957906232 + 6.938893903907228e-18im)
#
# Stacktrace:
#  [1] Real
#    @ .\complex.jl:44 [inlined]
#  [2] convert
#    @ .\number.jl:7 [inlined]
#  [3] setindex!(A::Vector{Float64}, x::ComplexF64, i1::Int64)
#    @ Base .\array.jl:903
#  [4] blockupop(n::Int64, supp::Matrix{UInt8}, coe::Vector{ComplexF64}, basis::Matrix{UInt8}, blocks::Vector{Vector{Int64}}, cl::Int64, blocksize::Vector{Int64}; nb::Int64, solver::String, feasible::Bool, QUIET::Bool, solve::Bool, solution::Bool, MomentOne::Bool, Gram::Bool)
#    @ TSSOS C:\Users\Zakhar\.julia\packages\TSSOS\drkzz\src\blockpop_uncons.jl:435
#  [5] tssos_first(f::Polynomial{true, ComplexF64}, x::Vector{PolyVar{true}}; nb::Int64, newton::Bool, reducebasis::Bool, TS::String, merge::Bool, feasible::Bool, md::Int64, solver::String, QUIET::Bool, solve::Bool, MomentOne::Bool, Gram::Bool, solution::Bool, tol::Float64)
#    @ TSSOS C:\Users\Zakhar\.julia\packages\TSSOS\drkzz\src\blockpop_uncons.jl:81
#  [6] tssos_first(f::Polynomial{true, ComplexF64}, x::Vector{PolyVar{true}})
#    @ TSSOS C:\Users\Zakhar\.julia\packages\TSSOS\drkzz\src\blockpop_uncons.jl:40
#  [7] top-level scope
#    @ In[52]:3
#  [8] eval
#    @ .\boot.jl:373 [inlined]
#  [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
