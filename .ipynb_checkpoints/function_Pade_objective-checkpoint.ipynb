# %% [markdown]
# ### Pade objective builder function

# %%
using Symbolics
using LinearAlgebra
using DynamicPolynomials

# %% [markdown]
# Auxilary function for square Frobenius norm of the matrix $\left\| M \right\|_F^2$:

# %%
function frobenius_norm2(m)
    return tr(m * m')
end
# Out:
# frobenius_norm2 (generic function with 1 method)

# %% [markdown]
# Lindblad master equation is given by
# \begin{align}\label{eq:L1}
#     \frac{d}{dt}{\rho}(t) = \mathcal{L}\rho(t),
# \end{align}

# %% [markdown]
# where Lindbladian right hand side operator is given as
# \begin{align}
#     \mathcal{L} [\rho] = - \frac{i}{\hbar}[H, \rho]+\sum_{j=1}^{\ell}\left[ J_j \rho J_j^\dagger - \frac{1}{2}\left\{ J_j^\dagger J_j, \rho \right\} \right],
# \end{align}

# %% [markdown]
# \begin{align}
# \sum_{i=1}^N {
# {\left\|
# \rho_{(i)} - \rho_{(i-1)}
# - {\mathcal{L}} \left[\int^{i\Delta t}_{(i-1)\Delta t}\rho(t)dt \right] \right\| }^2_F } \rightarrow \operatorname{min}
# \end{align}

# %%
function lindblad_rhs(ρ, H, J)
    """
    Right hand side of the Lindblad master equation
    """
    return -im*(H * ρ - ρ * H) + J * ρ * J' - (J' * J  * ρ + ρ * J' * J) / 2
    
end
# Out:
# lindblad_rhs (generic function with 1 method)

# %% [markdown]
# Terms for the objective for minimization:
# \begin{align}
# {\rho_{(i)} - \rho_{(i-1)} - \Delta t \mathcal{L} \left[\frac{{\rho}_{(i)} + {\rho}_{(i-1)}}{2} \right]} \rightarrow \operatorname{min}
# \end{align}

# %%
function pade_obj(ρ::Array{ComplexF64,3}, t, H, J)
    
    obj = 0
    for i in 2:size(ρ,3)
        obj += frobenius_norm2(
            ρ[:, :, i] - ρ[:, :, i-1] 
            - (t[i]-t[i-1])*lindblad_rhs((ρ[:, :, i]+ρ[:, :, i-1])/2, H, J)
        )
    end
    obj = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
    return obj
end

function pade_obj(ρ::Vector{Matrix{ComplexF64}}, t, H, J)
    obj = 0
    for i in 2:size(ρ,1)
        obj += frobenius_norm2(
            ρ[i] - ρ[i-1] 
            - (t[i]-t[i-1])*lindblad_rhs((ρ[i]+ρ[i-1])/2, H, J)
        )
    end
    obj = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
    return obj
end
# Out:
# pade_obj (generic function with 2 methods)

# %% [markdown]
# Consider test example

# %%
@polyvar x[1:4]
H = [ 1.0 * x[1]              x[3] + im * x[4]
      x[3] - im * x[4]        x[2]             ]

@polyvar a[1:2, 1:2]
@polyvar b[1:2, 1:2]
A = 1.0 * a + im * b

ρ1 = [.5 -im
     +im  .5]
ρ2 = [.6 0
     0  .4]
ρ3 = [.7 0
     0  .3]
ρ4 = [.9 0
     0  .1]

ρ = [ρ1;;; ρ2;;; ρ3;;; ρ4]
t = [0.0, 0.1, 0.2, 0.3]

obj = pade_obj(ρ, t, H, A)
# Out:
# 0.0012500000000000002a₁₋₁⁴ - 0.005000000000000001a₁₋₁³a₂₋₂ - 0.005500000000000001a₁₋₁³b₂₋₁ - 0.005000000000000001a₁₋₁³b₁₋₂ + 0.029799999999999997a₁₋₁²a₂₋₁² - 0.03499999999999999a₁₋₁²a₂₋₁a₁₋₂ + 0.005500000000000001a₁₋₁²a₂₋₁b₁₋₁ - 0.016000000000000004a₁₋₁²a₂₋₁b₂₋₂ + 0.017499999999999998a₁₋₁²a₁₋₂² + 0.005000000000000001a₁₋₁²a₁₋₂b₁₋₁ + 0.005500000000000001a₁₋₁²a₁₋₂b₂₋₂ + 0.0075000000000000015a₁₋₁²a₂₋₂² + 0.016000000000000004a₁₋₁²a₂₋₂b₂₋₁ + 0.014500000000000002a₁₋₁²a₂₋₂b₁₋₂ + 0.0025000000000000005a₁₋₁²b₁₋₁² - 0.005000000000000001a₁₋₁²b₁₋₁b₂₋₂ + 0.029799999999999997a₁₋₁²b₂₋₁² + 0.04499999999999999a₁₋₁²b₂₋₁b₁₋₂ + 0.0225a₁₋₁²b₁₋₂² + 0.0075000000000000015a₁₋₁²b₂₋₂² - 0.04499999999999999a₁₋₁a₂₋₁²a₂₋₂ - 0.005500000000000001a₁₋₁a₂₋₁²b₂₋₁ - 0.005000000000000001a₁₋₁a₂₋₁²b₁₋₂ + 0.04539999999999999a₁₋₁a₂₋₁a₁₋₂a₂₋₂ + 0.020000000000000004a₁₋₁a₂₋₁a₂₋₂b₂₋₂ - 0.07999999999999999a₁₋₁a₂₋₁b₁₋₁b₁₋₂ + 0.055399999999999984a₁₋₁a₂₋₁b₁₋₂b₂₋₂ - 0.025a₁₋₁a₁₋₂²a₂₋₂ - 0.015500000000000003a₁₋₁a₁₋₂²b₂₋₁ - 0.014000000000000002a₁₋₁a₁₋₂²b₁₋₂ - 0.020000000000000004a₁₋₁a₁₋₂a₂₋₂b₁₋₁ - 0.07999999999999999a₁₋₁a₁₋₂b₁₋₁b₂₋₁ - 0.010000000000000002a₁₋₁a₁₋₂b₁₋₁b₁₋₂ + 0.04539999999999999a₁₋₁a₁₋₂b₂₋₁b₂₋₂ - 0.005000000000000001a₁₋₁a₂₋₂³ - 0.015500000000000003a₁₋₁a₂₋₂²b₂₋₁ - 0.014000000000000002a₁₋₁a₂₋₂²b₁₋₂ - 0.005000000000000001a₁₋₁a₂₋₂b₁₋₁² - 0.04499999999999999a₁₋₁a₂₋₂b₂₋₁² - 0.05539999999999999a₁₋₁a₂₋₂b₂₋₁b₁₋₂ - 0.025a₁₋₁a₂₋₂b₁₋₂² - 0.005000000000000001a₁₋₁a₂₋₂b₂₋₂² - 0.005500000000000001a₁₋₁b₁₋₁²b₂₋₁ - 0.005000000000000001a₁₋₁b₁₋₁²b₁₋₂ + 0.020000000000000004a₁₋₁b₁₋₁b₁₋₂b₂₋₂ - 0.005500000000000001a₁₋₁b₂₋₁³ - 0.005000000000000001a₁₋₁b₂₋₁²b₁₋₂ - 0.015500000000000003a₁₋₁b₂₋₁b₁₋₂² + 0.0045000000000000005a₁₋₁b₂₋₁b₂₋₂² - 0.014000000000000002a₁₋₁b₁₋₂³ - 0.014000000000000002a₁₋₁b₁₋₂b₂₋₂² + 0.028549999999999996a₂₋₁⁴ + 0.005000000000000001a₂₋₁³a₁₋₂ + 0.005500000000000001a₂₋₁³b₁₋₁ - 0.016000000000000004a₂₋₁³b₂₋₂ - 0.017899999999999996a₂₋₁²a₁₋₂² + 0.005000000000000001a₂₋₁²a₁₋₂b₁₋₁ - 0.014500000000000002a₂₋₁²a₁₋₂b₂₋₂ + 0.017499999999999998a₂₋₁²a₂₋₂² + 0.016000000000000004a₂₋₁²a₂₋₂b₂₋₁ + 0.014500000000000002a₂₋₁²a₂₋₂b₁₋₂ + 0.029799999999999997a₂₋₁²b₁₋₁² - 0.04499999999999999a₂₋₁²b₁₋₁b₂₋₂ + 0.05709999999999999a₂₋₁²b₂₋₁² + 0.005000000000000001a₂₋₁²b₂₋₁b₁₋₂ - 0.017899999999999996a₂₋₁²b₁₋₂² + 0.0225a₂₋₁²b₂₋₂² + 0.005000000000000001a₂₋₁a₁₋₂³ + 0.015500000000000003a₂₋₁a₁₋₂²b₁₋₁ - 0.005000000000000001a₂₋₁a₁₋₂²b₂₋₂ - 0.014999999999999998a₂₋₁a₁₋₂a₂₋₂² + 0.04499999999999999a₂₋₁a₁₋₂b₁₋₁² - 0.05539999999999999a₂₋₁a₁₋₂b₁₋₁b₂₋₂ + 0.005000000000000001a₂₋₁a₁₋₂b₂₋₁² + 0.005000000000000001a₂₋₁a₁₋₂b₁₋₂² + 0.025a₂₋₁a₁₋₂b₂₋₂² - 0.0045000000000000005a₂₋₁a₂₋₂²b₁₋₁ - 0.005000000000000001a₂₋₁a₂₋₂²b₂₋₂ + 0.04539999999999999a₂₋₁a₂₋₂b₁₋₁b₁₋₂ - 0.010000000000000002a₂₋₁a₂₋₂b₂₋₁b₂₋₂ - 0.039999999999999994a₂₋₁a₂₋₂b₁₋₂b₂₋₂ + 0.005500000000000001a₂₋₁b₁₋₁³ - 0.016000000000000004a₂₋₁b₁₋₁²b₂₋₂ + 0.005500000000000001a₂₋₁b₁₋₁b₂₋₁² + 0.015500000000000003a₂₋₁b₁₋₁b₁₋₂² + 0.015500000000000003a₂₋₁b₁₋₁b₂₋₂² - 0.016000000000000004a₂₋₁b₂₋₁²b₂₋₂ - 0.005000000000000001a₂₋₁b₁₋₂²b₂₋₂ - 0.005000000000000001a₂₋₁b₂₋₂³ + 0.00855a₁₋₂⁴ + 0.014000000000000002a₁₋₂³b₁₋₁ - 0.0045000000000000005a₁₋₂³b₂₋₂ + 0.009800000000000001a₁₋₂²a₂₋₂² + 0.005000000000000001a₁₋₂²a₂₋₂b₂₋₁ + 0.0045000000000000005a₁₋₂²a₂₋₂b₁₋₂ + 0.0225a₁₋₂²b₁₋₁² - 0.025a₁₋₂²b₁₋₁b₂₋₂ - 0.017899999999999996a₁₋₂²b₂₋₁² + 0.005000000000000001a₁₋₂²b₂₋₁b₁₋₂ + 0.0171a₁₋₂²b₁₋₂² + 0.009800000000000001a₁₋₂²b₂₋₂² + 0.014000000000000002a₁₋₂a₂₋₂²b₁₋₁ - 0.0045000000000000005a₁₋₂a₂₋₂²b₂₋₂ + 0.055399999999999984a₁₋₂a₂₋₂b₁₋₁b₂₋₁ - 0.039999999999999994a₁₋₂a₂₋₂b₂₋₁b₂₋₂ + 0.005000000000000001a₁₋₂b₁₋₁³ - 0.014500000000000002a₁₋₂b₁₋₁²b₂₋₂ + 0.005000000000000001a₁₋₂b₁₋₁b₂₋₁² + 0.014000000000000002a₁₋₂b₁₋₁b₁₋₂² + 0.014000000000000002a₁₋₂b₁₋₁b₂₋₂² - 0.014500000000000002a₁₋₂b₂₋₁²b₂₋₂ - 0.0045000000000000005a₁₋₂b₁₋₂²b₂₋₂ - 0.0045000000000000005a₁₋₂b₂₋₂³ + 0.0012500000000000002a₂₋₂⁴ + 0.005000000000000001a₂₋₂³b₂₋₁ + 0.0045000000000000005a₂₋₂³b₁₋₂ + 0.0075000000000000015a₂₋₂²b₁₋₁² - 0.005000000000000001a₂₋₂²b₁₋₁b ...

# %%
using TSSOS

opt,sol,data = tssos_first(obj, variables(obj));
# Out:
# ************************TSSOS************************
# TSSOS is launching...
# Starting to compute the block structure...
# ------------------------------------------------------
# The sizes of PSD blocks:
# [22, 19, 4]
# [1, 1, 2]
# ------------------------------------------------------
# Obtained the block structure. The maximal size of blocks is 22.
# Assembling the SDP...
# There are 267 affine constraints.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 267
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 4
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 267
#   Cones                  : 0
#   Scalar variables       : 1
#   Matrix variables       : 4
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 267
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 2                 conic                  : 2
# Optimizer  - Semi-definite variables: 4                 scalarized             : 463
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.97e+04          after factor           : 2.97e+04
# Factor     - dense dim.             : 0                 flops                  : 4.45e+06
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.1e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   3.9e-01  3.4e-01  9.8e-02  3.16e-01   6.208376476e-01   8.587015113e-01   3.4e-01  0.05
# 2   6.2e-02  5.4e-02  1.1e-02  5.99e-01   1.350921459e+00   1.375128651e+00   5.4e-02  0.05
# 3   1.4e-02  1.2e-02  1.6e-03  7.21e-01   1.063290309e+00   1.063357439e+00   1.2e-02  0.05
# 4   4.3e-03  3.8e-03  4.4e-04  4.11e-01   7.489486232e-01   7.440385704e-01   3.8e-03  0.06
# 5   1.1e-03  9.7e-04  1.2e-04  9.92e-03   4.507714970e-01   4.397258077e-01   9.7e-04  0.06
# 6   2.2e-04  1.9e-04  1.4e-05  6.30e-01   2.325624911e-01   2.280954856e-01   1.9e-04  0.06
# 7   4.9e-05  4.3e-05  1.8e-06  6.86e-01   1.409788789e-01   1.395093683e-01   4.3e-05  0.06
# 8   1.4e-05  1.2e-05  2.5e-07  9.94e-01   1.055799610e-01   1.052572320e-01   1.2e-05  0.06
# 9   2.9e-06  2.5e-06  1.8e-08  1.16e+00   9.621318342e-02   9.617360267e-02   2.5e-06  0.06
# 10  6.9e-07  6.0e-07  2.4e-09  1.11e+00   9.436553886e-02   9.435277309e-02   6.0e-07  0.06
# 11  1.7e-07  1.5e-07  3.1e-10  1.03e+00   9.392154432e-02   9.391797001e-02   1.5e-07  0.06
# 12  4.2e-08  3.6e-08  3.9e-11  9.66e-01   9.381115585e-02   9.381020366e-02   3.6e-08  0.08
# 13  1.0e-08  8.7e-09  4.5e-12  1.07e+00   9.378257155e-02   9.378234930e-02   8.7e-09  0.08
# 14  2.4e-09  2.1e-09  5.7e-13  9.40e-01   9.377601274e-02   9.377595322e-02   2.1e-09  0.08
# 15  2.4e-09  6.7e-10  6.6e-14  1.08e+00   9.377429319e-02   9.377428031e-02   5.2e-10  0.08
# 16  2.7e-09  1.2e-09  8.3e-15  9.81e-01   9.377388923e-02   9.377388606e-02   1.3e-10  0.08
# Optimizer terminated. Time: 0.11
#
# SDP solving time: 1.093227 seconds.
# optimum = 0.09377388923399509

# %%
opt,sol,data = tssos_higher!(data);
# Out:
# Starting to compute the block structure...
# No higher TSSOS hierarchy!

# %%
opt,sol,data = tssos_higher!(data);
# Out:
# Starting to compute the block structure...
# No higher TSSOS hierarchy!
