# %% [markdown]
# ### Kraus objective minimization on Lindblad evolution

# %%
using Symbolics
using LinearAlgebra
using DynamicPolynomials

# %% [markdown]
# Auxilary function for square Frobenius norm of the matrix $\left\| M \right\|_F^2$:

# %%
function frobenius_norm2(m)
    return tr(m * m')
end
# Out:
# frobenius_norm2 (generic function with 1 method)

# %% [markdown]
# #### Consider Kraus evolution of quantum system

# %% [markdown]
# Consider Kraus map - a linear Completely Positive Trace Preserving (CP-TP) evolution of density matrix $\rho$:
# \begin{aligned}
#     \rho(t) & = \sum_{k=1}^{\ell} E_k^{} \rho(0) E_k^{\dagger}.
# \end{aligned}

# %% [markdown]
# The operators $\{E_k \}_{k=1}^{\ell}$ are called Kraus operators and satisfy the completeness relation $\sum_{k=1}^{\ell}E_k^\dagger E_k = \mathbb{1}$ with $\ell \leq n^2-1$.

# %% [markdown]
# #### The corresponding minimization problem

# %% [markdown]
#  Terms for the objective for minimization for evolution from $\rho_{(0)}$ to $\rho_{(1)}$:
# \begin{align}
# \left\| \sum_{k=1}^\ell \hat{E}_k \rho_{(0)} \hat{E}_k^{\dagger} - \rho_{(1)} \right\|_F^2
# \rightarrow \operatorname{min}
# \end{align}
# Under constraint:
# \begin{align}
# \sum_{k=1}^\ell \hat{E}_k^\dagger \hat{E}_k  = \mathbb{1}.
# \end{align}

# %% [markdown]
# For the time series of $\rho(t)$:
# \begin{align}
#     \sum_{i=0}^{N-1} \left\| \sum_{k=1}^\ell \hat{E}_k \rho_{(i)} \hat{E}_k^{\dagger} - \rho_{(i+1)} \right\|_F^2 \rightarrow \operatorname{min}
# \end{align}
#
# under constrain:
# \begin{align}
# \left \| \sum_{k=1}^\ell \hat{E}_k^\dagger \hat{E}_k  -\mathbb{1} \right\|_F^2 = 0
# \end{align}

# %% [markdown]
# The following function will essemble the Krauss objective from the time series of density matrix evolution:

# %%
import Base.real
function real(p::AbstractPolynomial)
    sum(real(coef) * mon for (coef, mon) in zip(coefficients(p), monomials(p)) if ~isapproxzero(abs(coef)))
end

function kraus(ρ)
    
    @polyvar a1[1:2, 1:2]
    @polyvar b1[1:2, 1:2]
    K1 = 1.0 * a1 + im * b1

    @polyvar a2[1:2, 1:2]
    @polyvar b2[1:2, 1:2]
    K2 = 1.0 * a2 + im * b2
    
    obj = 0
    for i in 1:length(ρ)-1
        obj += frobenius_norm2(K1 * ρ[i] * K1' + K2 * ρ[i] * K2' - ρ[i+1])
    end
    
    obj = sum(real(coef) * mon for (coef, mon) in zip(coefficients(obj), monomials(obj)))
    
    constr = frobenius_norm2(K1'*K1 + K2'*K2 - I)
    
    #return real(obj), real(constr)
    return obj, constr
    
end

function kraus(ρ, K...) 
    obj = 0
    for i in 1:length(ρ)-1
        obj += frobenius_norm2(sum(k * ρ[i] * k' for k in K) - ρ[i+1])
    end
    constr = frobenius_norm2(sum(k' * k for k in K) - I)
    # return real(obj), real(constr)
    return obj, constr
end
# Out:
# kraus (generic function with 2 methods)

# %% [markdown]
# Consider toy example

# %%
include("LiPoSID.jl")
seed = 100
w = 0.0
t = [0:0.01:1;]
ρ = LiPoSID.rand_Linblad_w_noise(seed, w, t)


using Plots
plot(LiPoSID.bloch(ρ)')
# Out:
# (process:6044): GLib-GIO-WARNING **: 20:37:07.131: Unexpectedly, UWP app `Microsoft.MSPaint_6.2203.1037.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.MSPaint_8wekyb3d8bbwe!Microsoft.MSPaint') supports 17 extensions but has no verbs

# %%
obj, constr = kraus(ρ);

# %%
using MosekTools
using JuMP
using MomentTools

# %%
optimizer = optimizer_with_attributes(Mosek.Optimizer, "QUIET" => true)
# Out:
# MathOptInterface.OptimizerWithAttributes(Mosek.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.RawParameter("QUIET") => true])

# %%
obj_min, M = minimize(obj, [constr], [], variables(obj), 2, optimizer)
# Out:
# (-2.585828223563558e-7, A JuMP Model
# Minimization problem with:
# Variables: 4845
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 2 constraints
# `Vector{AffExpr}`-in-`MathOptInterface.PositiveSemidefiniteConeTriangle`: 1 constraint
# Model mode: AUTOMATIC
# CachingOptimizer state: NO_OPTIMIZER
# Solver name: No optimizer attached.
# Names registered in the model: basis, degree, dual, index, moments, monomials, nu, type, variables, y)

# %%
r = get_minimizers(M)
obj_min_vals = [obj(r[:,i]) for i=1:size(r)[2]]
best_candidate = r[:, argmin(obj_min_vals)]
# Out:
# 16-element Vector{Float64}:
#  -0.12384332464815682
#  -0.016244934156560805
#  -0.10684502637700657
#  -0.08089393051226774
#  -0.09170963354745754
#  -0.022580049543604666
#  -0.1622671158565776
#  -0.1599414270743892
#  -0.2952462002087277
#  -0.008552502728490428
#  -0.04428116254743696
#  -0.21339290531109711
#  -0.09236621998700754
#  -0.041493844320264636
#  -0.18776565853307173
#  -0.14838474250150518

# %%
using NLopt

guess = best_candidate

vars = variables(obj)
    
@assert length(vars) == length(guess)

function g(a...)
    # Converting polynomial expression to function to be minimize
    obj(vars => a)
end

model = Model(NLopt.Optimizer)

set_optimizer_attribute(model, "algorithm", :LD_MMA)

#set_silent(model)
@variable(model, y[1:length(vars)]);

for (var, init_val) in zip(y, guess)
    set_start_value(var, init_val)
end

#= if length(constr_list) > 0
    @constraint(model, constr_list)
end =# 

register(model, :g, length(y), g; autodiff = true)
@NLobjective(model, Min, g(y...))
JuMP.optimize!(model)
solution_kraus = vars => map(value, y)
# Out:
# PolyVar{true}[a1₁₋₁, a1₂₋₁, a1₁₋₂, a1₂₋₂, b1₁₋₁, b1₂₋₁, b1₁₋₂, b1₂₋₂, a2₁₋₁, a2₂₋₁, a2₁₋₂, a2₂₋₂, b2₁₋₁, b2₂₋₁, b2₁₋₂, b2₂₋₂] => [-0.2807826601652876, -0.00999278655293502, -0.2552430557065939, -0.20917366935866735, -0.42526976461457916, -0.030052641827212317, -0.27899581054712674, -0.5215479767281324, -0.7556537031208942, 0.053159610644950235, 0.2376563390803866, -0.6436515637299013, -0.3835045436582334, -0.06353008966075312, 0.014621949102530198, -0.2977155763320619]

# %%
function Kraus_type_series(solution,  ρ0, time_steps)
       
    @polyvar a1[1:2, 1:2]
    @polyvar b1[1:2, 1:2]
    K1_symb = 1.0 * a1 + im * b1

    @polyvar a2[1:2, 1:2]
    @polyvar b2[1:2, 1:2]
    K2_symb = 1.0 * a2 + im * b2
    
    K1_sid = convert(subs(K1_symb, solution), Matrix{ComplexF64})
    K2_sid = convert(subs(K2_symb, solution), Matrix{ComplexF64})

    ρ = LiPoSID.timeevolution_kraus(time_steps, ρ0, [K1_sid, K2_sid])

end
# Out:
# Kraus_type_series (generic function with 1 method)

# %%
typeof(Hermitian(ρ[1]))
# Out:
# Hermitian{ComplexF64, Matrix{ComplexF64}}

# %%
@polyvar a1[1:2, 1:2]
@polyvar b1[1:2, 1:2]
K1_symb = 1.0 * a1 + im * b1

@polyvar a2[1:2, 1:2]
@polyvar b2[1:2, 1:2]
K2_symb = 1.0 * a2 + im * b2

solution[1] =>
# Out:
# 16-element Vector{PolyVar{true}}:
#  a1₁₋₁
#  a1₂₋₁
#  a1₁₋₂
#  a1₂₋₂
#  b1₁₋₁
#  b1₂₋₁
#  b1₁₋₂
#  b1₂₋₂
#  a2₁₋₁
#  a2₂₋₁
#  a2₁₋₂
#  a2₂₋₂
#  b2₁₋₁
#  b2₂₋₁
#  b2₁₋₂
#  b2₂₋₂

# %%
K1_sid = subs(K1_symb, solution_kraus[1] => solution_kraus[2])
K2_sid = subs(K2_symb, solution_kraus[1] => solution_kraus[2])
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  a2₁₋₁ + (0.0+1.0im)b2₁₋₁  a2₁₋₂ + (0.0+1.0im)b2₁₋₂
#  a2₂₋₁ + (0.0+1.0im)b2₂₋₁  a2₂₋₂ + (0.0+1.0im)b2₂₋₂

# %%
K1_sid = convert(Matrix{ComplexF64}, K1_sid)
K2_sid = convert(Matrix{ComplexF64}, K2_sid)
# Out:
# InexactError: convert(ComplexF64, a1[1,1] + (0.0 + 1.0im)*b1[1,1])
#
# Stacktrace:
#   [1] convert(S::Type{ComplexF64}, p::Polynomial{true, ComplexF64})
#     @ MultivariatePolynomials C:\Users\Zakhar\.julia\packages\MultivariatePolynomials\vqcb5\src\conversion.jl:70
#   [2] setindex!
#     @ .\array.jl:903 [inlined]
#   [3] _unsafe_copyto!(dest::Matrix{ComplexF64}, doffs::Int64, src::Matrix{Polynomial{true, ComplexF64}}, soffs::Int64, n::Int64)
#     @ Base .\array.jl:253
#   [4] unsafe_copyto!
#     @ .\array.jl:307 [inlined]
#   [5] _copyto_impl!
#     @ .\array.jl:331 [inlined]
#   [6] copyto!
#     @ .\array.jl:317 [inlined]
#   [7] copyto!
#     @ .\array.jl:343 [inlined]
#   [8] copyto_axcheck!(dest::Matrix{ComplexF64}, src::Matrix{Polynomial{true, ComplexF64}})
#     @ Base .\abstractarray.jl:1104
#   [9] Array
#     @ .\array.jl:563 [inlined]
#  [10] convert(#unused#::Type{Matrix{ComplexF64}}, a::Matrix{Polynomial{true, ComplexF64}})
#     @ Base .\array.jl:554
#  [11] top-level scope
#     @ In[42]:1
#  [12] eval
#     @ .\boot.jl:373 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196

# %%
time_steps = length(t)
ρ_sid_kraus = Kraus_type_series(solution,  Hermitian(ρ[1]), time_steps)
plot(LiPoSID.bloch(ρ_sid_kraus)')
# Out:
# MethodError: First argument to `convert` must be a Type, got Polynomial{true, ComplexF64}[a1₁₋₁ + (0.0 + 1.0im)b1₁₋₁ a1₁₋₂ + (0.0 + 1.0im)b1₁₋₂; a1₂₋₁ + (0.0 + 1.0im)b1₂₋₁ a1₂₋₂ + (0.0 + 1.0im)b1₂₋₂]
#
# Stacktrace:
#  [1] Kraus_type_series(solution::Pair{Vector{PolyVar{true}}, Vector{Float64}}, ρ0::Hermitian{ComplexF64, Matrix{ComplexF64}}, time_steps::Int64)
#    @ Main .\In[22]:11
#  [2] top-level scope
#    @ In[23]:2
#  [3] eval
#    @ .\boot.jl:373 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
    fidelity_kraus = min_fidelity_between_series(ρ_sid_kraus, ρ)
